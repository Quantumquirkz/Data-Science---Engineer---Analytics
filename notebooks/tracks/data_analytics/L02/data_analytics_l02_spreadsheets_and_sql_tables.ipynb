# %% [markdown]
# # Data Analytics L02: Spreadsheets And SQL Tables
#
# Mission: `p018-da-l02-m01`
# Project anchor: `p018` `energy_consumption_segmentation`
#
# ## Guiding question
#
# What happened, why did it happen, and what decision should follow?
#
# ## Level intent
#
# Move from manual tabulation to reproducible filtering, grouping, and joins.
#
# ## Mathematical spine
#
# $$\text{rate} = \frac{\Delta y}{\Delta t}, \qquad \bar{x} = \frac{1}{n}\sum_{i=1}^n x_i$$

# %% [markdown]
# ## Competencies
#
# - Tabular schemas
# - Primary keys
# - Aggregation semantics
#
# ## Method
#
# Translate concepts into reproducible tables, arrays, files, or modules.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'data_analytics'
level = 'L02'
project_id = 'p018'
project_slug = 'energy_consumption_segmentation'
project_readme = Path('projects/energy_consumption_segmentation/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.energy_consumption_segmentation.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/energy_consumption_segmentation/README.md`](../../../projects/energy_consumption_segmentation/README.md)
# - Project notebook: `projects/energy_consumption_segmentation/notebooks/energy_consumption_segmentation.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
