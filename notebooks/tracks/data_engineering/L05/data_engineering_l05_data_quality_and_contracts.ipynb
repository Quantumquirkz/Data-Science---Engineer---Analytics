# %% [markdown]
# # Data Engineering L05: Data Quality And Contracts
#
# Mission: `p055-de-l05-m01`
# Project anchor: `p055` `optical_experiment_noise_characterization`
#
# ## Guiding question
#
# How does data move, stay valid, and remain trustworthy at scale?
#
# ## Level intent
#
# Express data validity as contracts, tests, and observability.
#
# ## Mathematical spine
#
# $$\text{throughput} = \frac{\text{records processed}}{\text{time}}, \qquad \text{latency} = t_{out} - t_{in}$$

# %% [markdown]
# ## Competencies
#
# - Null policy
# - Range checks
# - Schema contracts
#
# ## Method
#
# Build a baseline artifact and compare it against a stronger alternative.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'data_engineering'
level = 'L05'
project_id = 'p055'
project_slug = 'optical_experiment_noise_characterization'
project_readme = Path('projects/optical_experiment_noise_characterization/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.optical_experiment_noise_characterization.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/optical_experiment_noise_characterization/README.md`](../../../projects/optical_experiment_noise_characterization/README.md)
# - Project notebook: `projects/optical_experiment_noise_characterization/notebooks/optical_experiment_noise_characterization.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
