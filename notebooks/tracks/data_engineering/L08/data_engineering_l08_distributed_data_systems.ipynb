# %% [markdown]
# # Data Engineering L08: Distributed Data Systems
#
# Mission: `p071-de-l08-m01`
# Project anchor: `p071` `renewable_energy_mix_optimizer`
#
# ## Guiding question
#
# How does data move, stay valid, and remain trustworthy at scale?
#
# ## Level intent
#
# Design data movement under partitioning, parallelism, and skew.
#
# ## Mathematical spine
#
# $$\text{throughput} = \frac{\text{records processed}}{\text{time}}, \qquad \text{latency} = t_{out} - t_{in}$$

# %% [markdown]
# ## Competencies
#
# - Sharding
# - Skew mitigation
# - Storage layout
#
# ## Method
#
# Scale the method while preserving observability and interpretability.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'data_engineering'
level = 'L08'
project_id = 'p071'
project_slug = 'renewable_energy_mix_optimizer'
project_readme = Path('projects/renewable_energy_mix_optimizer/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.renewable_energy_mix_optimizer.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/renewable_energy_mix_optimizer/README.md`](../../../projects/renewable_energy_mix_optimizer/README.md)
# - Project notebook: `projects/renewable_energy_mix_optimizer/notebooks/renewable_energy_mix_optimizer.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
