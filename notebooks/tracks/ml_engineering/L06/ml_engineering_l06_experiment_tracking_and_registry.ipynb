# %% [markdown]
# # ML Engineering L06: Experiment Tracking And Registry
#
# Mission: `p068-mle-l06-m01`
# Project anchor: `p068` `recommender_system_for_scientific_papers`
#
# ## Guiding question
#
# How does a model become a reliable, reproducible, inspectable software system?
#
# ## Level intent
#
# Version runs, metrics, and models without losing comparability.
#
# ## Mathematical spine
#
# $$\mathcal{L}(\theta) = \frac{1}{n}\sum_{i=1}^n \ell\left(f_\theta(x_i), y_i\right), \qquad \text{SLO}=\{\text{latency},\text{availability},\text{quality}\}$$

# %% [markdown]
# ## Competencies
#
# - Run lineage
# - Model registry semantics
# - Promotion criteria
#
# ## Method
#
# Track uncertainty, variation, retries, or experimental lineage.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'ml_engineering'
level = 'L06'
project_id = 'p068'
project_slug = 'recommender_system_for_scientific_papers'
project_readme = Path('projects/recommender_system_for_scientific_papers/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.recommender_system_for_scientific_papers.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/recommender_system_for_scientific_papers/README.md`](../../../projects/recommender_system_for_scientific_papers/README.md)
# - Project notebook: `projects/recommender_system_for_scientific_papers/notebooks/recommender_system_for_scientific_papers.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
