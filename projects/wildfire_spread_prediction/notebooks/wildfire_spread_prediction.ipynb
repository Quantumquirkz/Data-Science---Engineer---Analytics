# %% [markdown]
# # Wildfire Spread Prediction
#
# Predict the likely spread of wildfires using weather, terrain, and vegetation data.

# %%
from pathlib import Path
from projects.wildfire_spread_prediction.src.pipeline import run_wildfire_spread_prediction_pipeline
artifacts = run_wildfire_spread_prediction_pipeline(Path('projects/wildfire_spread_prediction'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
