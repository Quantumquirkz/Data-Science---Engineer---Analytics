# %% [markdown]
# # ML Engineering L05: Model Packaging And Serving
#
# Mission: `p059-mle-l05-m01`
# Project anchor: `p059` `physics_informed_weather_nowcasting`
#
# ## Guiding question
#
# How does a model become a reliable, reproducible, inspectable software system?
#
# ## Level intent
#
# Turn models into callable systems with stable inference contracts.
#
# ## Mathematical spine
#
# $$\mathcal{L}(\theta) = \frac{1}{n}\sum_{i=1}^n \ell\left(f_\theta(x_i), y_i\right), \qquad \text{SLO}=\{\text{latency},\text{availability},\text{quality}\}$$

# %% [markdown]
# ## Competencies
#
# - Input schemas
# - Prediction interfaces
# - Cold-start costs
#
# ## Method
#
# Build a baseline artifact and compare it against a stronger alternative.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'ml_engineering'
level = 'L05'
project_id = 'p059'
project_slug = 'physics_informed_weather_nowcasting'
project_readme = Path('projects/physics_informed_weather_nowcasting/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.physics_informed_weather_nowcasting.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/physics_informed_weather_nowcasting/README.md`](../../../projects/physics_informed_weather_nowcasting/README.md)
# - Project notebook: `projects/physics_informed_weather_nowcasting/notebooks/physics_informed_weather_nowcasting.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
