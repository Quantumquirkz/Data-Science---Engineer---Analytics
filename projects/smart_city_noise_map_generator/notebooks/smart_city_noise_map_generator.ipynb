# %% [markdown]
# # Smart City Noise Map Generator
#
# Build dynamic urban noise maps using open city sound datasets, municipality sensor archives, and spatial interpolation.

# %%
from pathlib import Path
from projects.smart_city_noise_map_generator.src.pipeline import run_smart_city_noise_map_generator_pipeline
artifacts = run_smart_city_noise_map_generator_pipeline(Path('projects/smart_city_noise_map_generator'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
