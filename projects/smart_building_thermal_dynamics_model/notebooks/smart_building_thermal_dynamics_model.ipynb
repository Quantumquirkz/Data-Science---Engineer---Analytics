# %% [markdown]
# # Smart Building Thermal Dynamics Model
#
# Estimate indoor temperature evolution from open building energy datasets, occupancy proxies, and weather data.

# %%
from pathlib import Path
from projects.smart_building_thermal_dynamics_model.src.pipeline import run_smart_building_thermal_dynamics_model_pipeline
artifacts = run_smart_building_thermal_dynamics_model_pipeline(Path('projects/smart_building_thermal_dynamics_model'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
