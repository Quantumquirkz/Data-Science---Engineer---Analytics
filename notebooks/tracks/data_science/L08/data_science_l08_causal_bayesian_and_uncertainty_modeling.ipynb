# %% [markdown]
# # Data Science L08: Causal, Bayesian, And Uncertainty Modeling
#
# Mission: `p037-ds-l08-m01`
# Project anchor: `p037` `hydrological_flood_risk_forecasting`
#
# ## Guiding question
#
# What pattern is real, what prediction is useful, and how uncertain are we?
#
# ## Level intent
#
# Represent beliefs, uncertainty, and interventions explicitly.
#
# ## Mathematical spine
#
# $$P(A\mid B) = \frac{P(B\mid A)P(A)}{P(B)}, \qquad \hat{y} = f_\theta(x)$$

# %% [markdown]
# ## Competencies
#
# - Bayesian updating
# - Posterior reasoning
# - Causal diagrams
#
# ## Method
#
# Scale the method while preserving observability and interpretability.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'data_science'
level = 'L08'
project_id = 'p037'
project_slug = 'hydrological_flood_risk_forecasting'
project_readme = Path('projects/hydrological_flood_risk_forecasting/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.hydrological_flood_risk_forecasting.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/hydrological_flood_risk_forecasting/README.md`](../../../projects/hydrological_flood_risk_forecasting/README.md)
# - Project notebook: `projects/hydrological_flood_risk_forecasting/notebooks/hydrological_flood_risk_forecasting.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
