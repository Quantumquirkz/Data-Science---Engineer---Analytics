# %% [markdown]
# # Satellite Image Change Detection
#
# Detect land-use or environmental changes from multi-temporal satellite imagery.

# %%
from pathlib import Path
from projects.satellite_image_change_detection.src.pipeline import run_satellite_image_change_detection_pipeline
artifacts = run_satellite_image_change_detection_pipeline(Path('projects/satellite_image_change_detection'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
