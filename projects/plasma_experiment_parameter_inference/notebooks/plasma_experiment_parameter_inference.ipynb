# %% [markdown]
# # Plasma Experiment Parameter Inference
#
# Infer plasma model parameters from published observational datasets, open tokamak benchmarks, or simulated measurements.

# %%
from pathlib import Path
from projects.plasma_experiment_parameter_inference.src.pipeline import run_plasma_experiment_parameter_inference_pipeline
artifacts = run_plasma_experiment_parameter_inference_pipeline(Path('projects/plasma_experiment_parameter_inference'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
