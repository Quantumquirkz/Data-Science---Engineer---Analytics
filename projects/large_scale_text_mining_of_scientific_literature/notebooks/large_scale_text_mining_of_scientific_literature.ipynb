# %% [markdown]
# # Large-Scale Text Mining of Scientific Literature
#
# Extract themes, trends, and emerging concepts from thousands of scientific papers.

# %%
from pathlib import Path
from projects.large_scale_text_mining_of_scientific_literature.src.pipeline import run_large_scale_text_mining_of_scientific_literature_pipeline
artifacts = run_large_scale_text_mining_of_scientific_literature_pipeline(Path('projects/large_scale_text_mining_of_scientific_literature'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
