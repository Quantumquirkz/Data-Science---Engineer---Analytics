# %% [markdown]
# # Neutrino Detector Event Clustering
#
# Cluster detector events to separate noise from meaningful high-energy interactions.

# %%
from pathlib import Path
from projects.neutrino_detector_event_clustering.src.pipeline import run_neutrino_detector_event_clustering_pipeline
artifacts = run_neutrino_detector_event_clustering_pipeline(Path('projects/neutrino_detector_event_clustering'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
