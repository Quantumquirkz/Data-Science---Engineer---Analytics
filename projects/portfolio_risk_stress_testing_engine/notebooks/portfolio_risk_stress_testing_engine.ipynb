# %% [markdown]
# # Portfolio Risk Stress Testing Engine
#
# Build a framework to stress test portfolios under simulated macro and volatility shocks.

# %%
from pathlib import Path
from projects.portfolio_risk_stress_testing_engine.src.pipeline import run_portfolio_risk_stress_testing_engine_pipeline
artifacts = run_portfolio_risk_stress_testing_engine_pipeline(Path('projects/portfolio_risk_stress_testing_engine'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
