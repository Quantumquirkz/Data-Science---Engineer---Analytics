# %% [markdown]
# # Sports Tournament Simulation Engine
#
# Simulate tournament outcomes from player or team strength distributions.

# %%
from pathlib import Path
from projects.sports_tournament_simulation_engine.src.pipeline import run_sports_tournament_simulation_engine_pipeline
artifacts = run_sports_tournament_simulation_engine_pipeline(Path('projects/sports_tournament_simulation_engine'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
