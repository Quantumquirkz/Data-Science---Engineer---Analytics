# %% [markdown]
# # Rare Disease Signal Mining
#
# Detect weak disease signals in very imbalanced healthcare or genomic datasets.

# %%
from pathlib import Path
from projects.rare_disease_signal_mining.src.pipeline import run_rare_disease_signal_mining_pipeline
artifacts = run_rare_disease_signal_mining_pipeline(Path('projects/rare_disease_signal_mining'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
