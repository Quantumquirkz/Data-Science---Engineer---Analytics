# %% [markdown]
# # Battery Degradation Modeling
#
# Predict battery health and remaining useful life from public battery cycle datasets collected in prior experiments.

# %%
from pathlib import Path
from projects.battery_degradation_modeling.src.pipeline import run_battery_degradation_modeling_pipeline
artifacts = run_battery_degradation_modeling_pipeline(Path('projects/battery_degradation_modeling'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
