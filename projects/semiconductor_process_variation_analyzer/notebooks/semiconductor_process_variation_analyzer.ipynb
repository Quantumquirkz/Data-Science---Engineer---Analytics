# %% [markdown]
# # Semiconductor Process Variation Analyzer
#
# Analyze manufacturing variation and defect propagation in semiconductor process data.

# %%
from pathlib import Path
from projects.semiconductor_process_variation_analyzer.src.pipeline import run_semiconductor_process_variation_analyzer_pipeline
artifacts = run_semiconductor_process_variation_analyzer_pipeline(Path('projects/semiconductor_process_variation_analyzer'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
