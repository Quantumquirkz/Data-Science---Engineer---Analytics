# %% [markdown]
# # Computational Topology for Data Shapes
#
# Study the shape of high-dimensional datasets using topological summaries.

# %%
from pathlib import Path
from projects.computational_topology_for_data_shapes.src.pipeline import run_computational_topology_for_data_shapes_pipeline
artifacts = run_computational_topology_for_data_shapes_pipeline(Path('projects/computational_topology_for_data_shapes'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
