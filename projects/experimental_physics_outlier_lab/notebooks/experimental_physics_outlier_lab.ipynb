# %% [markdown]
# # Experimental Physics Outlier Lab
#
# Build tools to identify suspicious measurements in repeated physics experiments using open lab datasets or synthetic repeated-measurement tables.

# %%
from pathlib import Path
from projects.experimental_physics_outlier_lab.src.pipeline import run_experimental_physics_outlier_lab_pipeline
artifacts = run_experimental_physics_outlier_lab_pipeline(Path('projects/experimental_physics_outlier_lab'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
