# %% [markdown]
# # Renewable Energy Mix Optimizer
#
# Optimize the allocation of solar, wind, and storage resources over time.

# %%
from pathlib import Path
from projects.renewable_energy_mix_optimizer.src.pipeline import run_renewable_energy_mix_optimizer_pipeline
artifacts = run_renewable_energy_mix_optimizer_pipeline(Path('projects/renewable_energy_mix_optimizer'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
