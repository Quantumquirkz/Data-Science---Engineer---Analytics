# %% [markdown]
# # Data Science L06: Unsupervised Learning
#
# Mission: `p031-ds-l06-m01`
# Project anchor: `p031` `high_dimensional_feature_selection_lab`
#
# ## Guiding question
#
# What pattern is real, what prediction is useful, and how uncertain are we?
#
# ## Level intent
#
# Cluster, reduce dimension, and discover latent structure responsibly.
#
# ## Mathematical spine
#
# $$P(A\mid B) = \frac{P(B\mid A)P(A)}{P(B)}, \qquad \hat{y} = f_\theta(x)$$

# %% [markdown]
# ## Competencies
#
# - Distance choice
# - Cluster validity
# - Representation learning
#
# ## Method
#
# Track uncertainty, variation, retries, or experimental lineage.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'data_science'
level = 'L06'
project_id = 'p031'
project_slug = 'high_dimensional_feature_selection_lab'
project_readme = Path('projects/high_dimensional_feature_selection_lab/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.high_dimensional_feature_selection_lab.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/high_dimensional_feature_selection_lab/README.md`](../../../projects/high_dimensional_feature_selection_lab/README.md)
# - Project notebook: `projects/high_dimensional_feature_selection_lab/notebooks/high_dimensional_feature_selection_lab.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
