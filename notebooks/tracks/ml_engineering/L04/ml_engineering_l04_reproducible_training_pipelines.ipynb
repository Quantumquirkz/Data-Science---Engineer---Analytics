# %% [markdown]
# # ML Engineering L04: Reproducible Training Pipelines
#
# Mission: `p050-mle-l04-m01`
# Project anchor: `p050` `neuron_spike_train_modeling`
#
# ## Guiding question
#
# How does a model become a reliable, reproducible, inspectable software system?
#
# ## Level intent
#
# Capture seeds, configs, and dependencies so results can be repeated.
#
# ## Mathematical spine
#
# $$\mathcal{L}(\theta) = \frac{1}{n}\sum_{i=1}^n \ell\left(f_\theta(x_i), y_i\right), \qquad \text{SLO}=\{\text{latency},\text{availability},\text{quality}\}$$

# %% [markdown]
# ## Competencies
#
# - Configuration surfaces
# - Artifact capture
# - Experiment traceability
#
# ## Method
#
# Make assumptions explicit and test whether the method still holds.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'ml_engineering'
level = 'L04'
project_id = 'p050'
project_slug = 'neuron_spike_train_modeling'
project_readme = Path('projects/neuron_spike_train_modeling/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.neuron_spike_train_modeling.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/neuron_spike_train_modeling/README.md`](../../../projects/neuron_spike_train_modeling/README.md)
# - Project notebook: `projects/neuron_spike_train_modeling/notebooks/neuron_spike_train_modeling.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
