# %% [markdown]
# # Human Activity Recognition from Wearables
#
# Recognize physical activities from public accelerometer and gyroscope datasets collected from wearables or smartphones.

# %%
from pathlib import Path
from projects.human_activity_recognition_from_wearables.src.pipeline import run_human_activity_recognition_from_wearables_pipeline
artifacts = run_human_activity_recognition_from_wearables_pipeline(Path('projects/human_activity_recognition_from_wearables'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
