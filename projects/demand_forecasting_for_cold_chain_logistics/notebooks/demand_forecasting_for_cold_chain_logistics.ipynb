# %% [markdown]
# # Demand Forecasting for Cold Chain Logistics
#
# Forecast demand and spoilage risk in temperature-sensitive supply chains.

# %%
from pathlib import Path
from projects.demand_forecasting_for_cold_chain_logistics.src.pipeline import run_demand_forecasting_for_cold_chain_logistics_pipeline
artifacts = run_demand_forecasting_for_cold_chain_logistics_pipeline(Path('projects/demand_forecasting_for_cold_chain_logistics'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
