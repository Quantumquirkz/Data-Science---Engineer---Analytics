# %% [markdown]
# # Ocean Current Field Compression
#
# Compress and reconstruct ocean current fields from massive spatiotemporal datasets.

# %%
from pathlib import Path
from projects.ocean_current_field_compression.src.pipeline import run_ocean_current_field_compression_pipeline
artifacts = run_ocean_current_field_compression_pipeline(Path('projects/ocean_current_field_compression'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
