# %% [markdown]
# # Data Science L02: Python, NumPy, And pandas
#
# Mission: `p014-ds-l02-m01`
# Project anchor: `p014` `demand_forecasting_for_cold_chain_logistics`
#
# ## Guiding question
#
# What pattern is real, what prediction is useful, and how uncertain are we?
#
# ## Level intent
#
# Use the core Python data stack to inspect, clean, and transform evidence.
#
# ## Mathematical spine
#
# $$P(A\mid B) = \frac{P(B\mid A)P(A)}{P(B)}, \qquad \hat{y} = f_\theta(x)$$

# %% [markdown]
# ## Competencies
#
# - Arrays
# - Data frames
# - Vectorized thinking
#
# ## Method
#
# Translate concepts into reproducible tables, arrays, files, or modules.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'data_science'
level = 'L02'
project_id = 'p014'
project_slug = 'demand_forecasting_for_cold_chain_logistics'
project_readme = Path('projects/demand_forecasting_for_cold_chain_logistics/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.demand_forecasting_for_cold_chain_logistics.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/demand_forecasting_for_cold_chain_logistics/README.md`](../../../projects/demand_forecasting_for_cold_chain_logistics/README.md)
# - Project notebook: `projects/demand_forecasting_for_cold_chain_logistics/notebooks/demand_forecasting_for_cold_chain_logistics.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
