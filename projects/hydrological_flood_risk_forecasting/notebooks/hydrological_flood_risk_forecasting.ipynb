# %% [markdown]
# # Hydrological Flood Risk Forecasting
#
# Forecast flood risk using rainfall, river level, and terrain information.

# %%
from pathlib import Path
from projects.hydrological_flood_risk_forecasting.src.pipeline import run_hydrological_flood_risk_forecasting_pipeline
artifacts = run_hydrological_flood_risk_forecasting_pipeline(Path('projects/hydrological_flood_risk_forecasting'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
