# %% [markdown]
# # Warehouse Robotics Path Optimization
#
# Optimize robot routing and collision avoidance in a warehouse environment using simulated layouts, public routing benchmarks, or synthetic traffic data.

# %%
from pathlib import Path
from projects.warehouse_robotics_path_optimization.src.pipeline import run_warehouse_robotics_path_optimization_pipeline
artifacts = run_warehouse_robotics_path_optimization_pipeline(Path('projects/warehouse_robotics_path_optimization'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
