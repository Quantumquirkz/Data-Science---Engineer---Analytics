# %% [markdown]
# # Electromagnetic Interference Pattern Detector
#
# Detect interference patterns in electronic systems using frequency-domain data.

# %%
from pathlib import Path
from projects.electromagnetic_interference_pattern_detector.src.pipeline import run_electromagnetic_interference_pattern_detector_pipeline
artifacts = run_electromagnetic_interference_pattern_detector_pipeline(Path('projects/electromagnetic_interference_pattern_detector'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
