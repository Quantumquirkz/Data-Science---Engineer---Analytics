# %% [markdown]
# # Foundations Orientation
#
# This notebook is the first central notebook for the **Foundations** learning track.
#
# ## Guiding question
#
# How do concepts, code, and evidence reinforce each other in an open repository?
#
# ## Mathematical spine
#
# $$\text{learning} = \text{concept} + \text{practice} + \text{reflection}$$
#
# ## Evidence contract
#
# - Explain the observation unit.
# - Identify one assumption.
# - Write one likely error mode.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'foundations'
repo_root, track

# %% [markdown]
# ## Practice prompt
#
# Write a short explanation of what counts as signal, noise, and decision in this discipline.
