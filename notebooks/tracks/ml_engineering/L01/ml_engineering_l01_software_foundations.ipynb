# %% [markdown]
# # ML Engineering L01: Software Foundations
#
# Mission: `p034-mle-l01-m01`
# Project anchor: `p034` `human_activity_recognition_from_wearables`
#
# ## Guiding question
#
# How does a model become a reliable, reproducible, inspectable software system?
#
# ## Level intent
#
# Treat scripts, modules, tests, and environments as first-class ML assets.
#
# ## Mathematical spine
#
# $$\mathcal{L}(\theta) = \frac{1}{n}\sum_{i=1}^n \ell\left(f_\theta(x_i), y_i\right), \qquad \text{SLO}=\{\text{latency},\text{availability},\text{quality}\}$$

# %% [markdown]
# ## Competencies
#
# - Python package boundaries
# - CLI execution
# - Determinism intuition
#
# ## Method
#
# Define the objects of study before using tooling.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'ml_engineering'
level = 'L01'
project_id = 'p034'
project_slug = 'human_activity_recognition_from_wearables'
project_readme = Path('projects/human_activity_recognition_from_wearables/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.human_activity_recognition_from_wearables.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/human_activity_recognition_from_wearables/README.md`](../../../projects/human_activity_recognition_from_wearables/README.md)
# - Project notebook: `projects/human_activity_recognition_from_wearables/notebooks/human_activity_recognition_from_wearables.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
