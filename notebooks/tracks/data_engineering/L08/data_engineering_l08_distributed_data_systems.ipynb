# %% [markdown]
# # Data Engineering L08: Distributed Data Systems
#
# This notebook teaches the level step by step. It assumes you are willing to slow down and define the idea before running project code.
#
# **Mission:** `p071-de-l08-m01`
# **Project anchor:** `p071` `renewable_energy_mix_optimizer`
#
# ## Start from zero
#
# Design data movement under partitioning, parallelism, and skew.
#
# Plain question: **How does data move, stay valid, and remain trustworthy at scale?**

# %% [markdown]
# ## 1. Vocabulary before tools
#
# Before using libraries, define the vocabulary.
#
# - `Sharding`: write a one-sentence definition.
# - `Skew mitigation`: point to where it appears in data, code, math, or system design.
# - `Storage layout`: explain the risk if it is ignored.
#
# A useful rule: if you cannot explain the word with a tiny example, you are not ready to automate it.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'data_engineering'
level = 'L08'
project_id = 'p071'
project_slug = 'renewable_energy_mix_optimizer'
project_readme = Path('projects') / project_slug / 'README.md'
project_notebook = 'projects/renewable_energy_mix_optimizer/notebooks/renewable_energy_mix_optimizer.ipynb'

{
    'repo_root': str(repo_root),
    'track': track,
    'level': level,
    'project_readme_exists': project_readme.exists(),
    'project_notebook': project_notebook,
}

# %% [markdown]
# ## 2. The core idea slowly
#
# This is the **Scale** stage. Your job is to preserve clarity when data, compute, users, or models grow.
#
# Scaling a weak idea makes the weakness more expensive.
#
# Every level in this repository follows the same reasoning chain:
#
# 1. Observation: what is directly visible?
# 2. Representation: how is it encoded?
# 3. Operation: what do we compute or transform?
# 4. Evidence: what output supports the claim?
# 5. Limitation: what could still be wrong?

# %% [markdown]
# ## 3. Mathematical spine
#
# \[\text{throughput} = \frac{\text{records processed}}{\text{time}}, \qquad \text{latency} = t_{out} - t_{in}\]
#
# Throughput measures how much work a system completes per unit time. Latency measures how long one item takes to travel through the system.
#
# At this level, do not try to memorize symbols. Translate each symbol into words and connect it to the project anchor.

# %%
learning_card = {
    'track': 'Data Engineering',
    'level': 'L08',
    'title': 'Distributed Data Systems',
    'mission': 'p071-de-l08-m01',
    'project': 'renewable_energy_mix_optimizer',
    'competencies': ['Sharding', 'Skew mitigation', 'Storage layout'],
    'first_principle': 'data engineering starts with movement, structure, contracts, and failure recovery',
}

for key, value in learning_card.items():
    print(f"{key}: {value}")

# %% [markdown]
# ## 4. Worked micro-example
#
# Imagine a folder of daily log files. You need to know where each file comes from, what schema it claims to follow, and how storage layout would appear when something breaks.
#
# Now answer:
#
# - What is the observation?
# - What is the representation?
# - What operation is being applied?
# - What output would count as evidence?
# - What limitation remains?

# %%
exercise = {
    'observation': '',
    'representation': '',
    'operation': '',
    'evidence': '',
    'limitation': '',
}

# Fill the strings above as notes while studying. Keeping them in a dict makes
# the reasoning explicit and easy to revise.
exercise

# %% [markdown]
# ## 5. Connect to the project
#
# Open the project README and notebook after you understand the vocabulary.
#
# Project README path:
#
# ```text
# projects/renewable_energy_mix_optimizer/README.md
# ```
#
# Run command:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.renewable_energy_mix_optimizer.src.pipeline
# ```
#
# Do not worry if the project feels more advanced than the level. Your task is to identify where this level's idea appears inside the project.

# %% [markdown]
# ## 6. Self-check without grades
#
# Mark yourself honestly:
#
# - `exploring`: I can repeat the words.
# - `practiced`: I can run this notebook and answer the prompts.
# - `demonstrated`: I can explain `Distributed Data Systems` using `renewable_energy_mix_optimizer`.
# - `extended`: I changed an assumption or proposed a stronger experiment.
#
# Before leaving the notebook, write one sentence for each competency: `Sharding`, `Skew mitigation`, and `Storage layout`.
