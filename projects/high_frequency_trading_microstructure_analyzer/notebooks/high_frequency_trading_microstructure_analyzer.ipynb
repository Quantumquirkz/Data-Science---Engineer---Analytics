# %% [markdown]
# # High-Frequency Trading Microstructure Analyzer
#
# Analyze order book dynamics and price micro-movements from tick-level market data.

# %%
from pathlib import Path
from projects.high_frequency_trading_microstructure_analyzer.src.pipeline import run_high_frequency_trading_microstructure_analyzer_pipeline
artifacts = run_high_frequency_trading_microstructure_analyzer_pipeline(Path('projects/high_frequency_trading_microstructure_analyzer'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
