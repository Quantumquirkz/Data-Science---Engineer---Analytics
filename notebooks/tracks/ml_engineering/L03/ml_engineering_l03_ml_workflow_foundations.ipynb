# %% [markdown]
# # ML Engineering L03: ML Workflow Foundations
#
# Mission: `p041-mle-l03-m01`
# Project anchor: `p041` `large_scale_recommendation_for_learning_paths`
#
# ## Guiding question
#
# How does a model become a reliable, reproducible, inspectable software system?
#
# ## Level intent
#
# Separate data loading, feature logic, training, and evaluation cleanly.
#
# ## Mathematical spine
#
# $$\mathcal{L}(\theta) = \frac{1}{n}\sum_{i=1}^n \ell\left(f_\theta(x_i), y_i\right), \qquad \text{SLO}=\{\text{latency},\text{availability},\text{quality}\}$$

# %% [markdown]
# ## Competencies
#
# - Pipeline stages
# - Artifact naming
# - Re-run safety
#
# ## Method
#
# Reason about structure: distributions, schemas, workflows, or equations.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'ml_engineering'
level = 'L03'
project_id = 'p041'
project_slug = 'large_scale_recommendation_for_learning_paths'
project_readme = Path('projects/large_scale_recommendation_for_learning_paths/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.large_scale_recommendation_for_learning_paths.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/large_scale_recommendation_for_learning_paths/README.md`](../../../projects/large_scale_recommendation_for_learning_paths/README.md)
# - Project notebook: `projects/large_scale_recommendation_for_learning_paths/notebooks/large_scale_recommendation_for_learning_paths.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
