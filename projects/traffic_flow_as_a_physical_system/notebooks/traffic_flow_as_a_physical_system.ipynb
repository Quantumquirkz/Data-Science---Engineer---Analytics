# %% [markdown]
# # Traffic Flow as a Physical System
#
# Study urban traffic as a dynamical system and predict congestion patterns.

# %%
from pathlib import Path
from projects.traffic_flow_as_a_physical_system.src.pipeline import run_traffic_flow_as_a_physical_system_pipeline
artifacts = run_traffic_flow_as_a_physical_system_pipeline(Path('projects/traffic_flow_as_a_physical_system'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
