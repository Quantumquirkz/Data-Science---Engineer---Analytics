# %% [markdown]
# # Online Experiment Bayesian Analyzer
#
# Build a Bayesian analytics tool for A/B tests with streaming observations.

# %%
from pathlib import Path
from projects.online_experiment_bayesian_analyzer.src.pipeline import run_online_experiment_bayesian_analyzer_pipeline
artifacts = run_online_experiment_bayesian_analyzer_pipeline(Path('projects/online_experiment_bayesian_analyzer'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
