# %% [markdown]
# # Data Science L10: Research-Grade Data Science Capstone
#
# Mission: `p095-ds-l10-m01`
# Project anchor: `p095` `traffic_flow_as_a_physical_system`
#
# ## Guiding question
#
# What pattern is real, what prediction is useful, and how uncertain are we?
#
# ## Level intent
#
# Produce a defensible study with reproducibility, diagnostics, and limitations.
#
# ## Mathematical spine
#
# $$P(A\mid B) = \frac{P(B\mid A)P(A)}{P(B)}, \qquad \hat{y} = f_\theta(x)$$

# %% [markdown]
# ## Competencies
#
# - Research protocol
# - Ablation logic
# - Interpretation boundaries
#
# ## Method
#
# Integrate the full track into a capstone-level system narrative.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'data_science'
level = 'L10'
project_id = 'p095'
project_slug = 'traffic_flow_as_a_physical_system'
project_readme = Path('projects/traffic_flow_as_a_physical_system/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.traffic_flow_as_a_physical_system.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/traffic_flow_as_a_physical_system/README.md`](../../../projects/traffic_flow_as_a_physical_system/README.md)
# - Project notebook: `projects/traffic_flow_as_a_physical_system/notebooks/traffic_flow_as_a_physical_system.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
