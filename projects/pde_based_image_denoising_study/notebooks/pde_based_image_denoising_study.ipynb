# %% [markdown]
# # PDE-Based Image Denoising Study
#
# Apply differential-equation-based denoising and compare against learned filters.

# %%
from pathlib import Path
from projects.pde_based_image_denoising_study.src.pipeline import run_pde_based_image_denoising_study_pipeline
artifacts = run_pde_based_image_denoising_study_pipeline(Path('projects/pde_based_image_denoising_study'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
