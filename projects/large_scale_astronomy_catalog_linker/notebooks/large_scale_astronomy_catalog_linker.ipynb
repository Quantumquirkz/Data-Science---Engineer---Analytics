# %% [markdown]
# # Large-Scale Astronomy Catalog Linker
#
# Match records across multiple astronomical catalogs with uncertain coordinates and metadata.

# %%
from pathlib import Path
from projects.large_scale_astronomy_catalog_linker.src.pipeline import run_large_scale_astronomy_catalog_linker_pipeline
artifacts = run_large_scale_astronomy_catalog_linker_pipeline(Path('projects/large_scale_astronomy_catalog_linker'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
