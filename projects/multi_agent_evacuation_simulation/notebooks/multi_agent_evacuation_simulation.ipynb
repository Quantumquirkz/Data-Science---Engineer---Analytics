# %% [markdown]
# # Multi-Agent Evacuation Simulation
#
# Simulate evacuation dynamics in buildings or stadiums under different constraints.

# %%
from pathlib import Path
from projects.multi_agent_evacuation_simulation.src.pipeline import run_multi_agent_evacuation_simulation_pipeline
artifacts = run_multi_agent_evacuation_simulation_pipeline(Path('projects/multi_agent_evacuation_simulation'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
