# %% [markdown]
# # Reservoir Pressure Forecasting
#
# Predict pressure evolution in reservoirs using published extraction records, benchmark reservoir datasets, or synthetic sensor data.

# %%
from pathlib import Path
from projects.reservoir_pressure_forecasting.src.pipeline import run_reservoir_pressure_forecasting_pipeline
artifacts = run_reservoir_pressure_forecasting_pipeline(Path('projects/reservoir_pressure_forecasting'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
