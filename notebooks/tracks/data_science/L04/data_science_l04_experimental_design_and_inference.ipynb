# %% [markdown]
# # Data Science L04: Experimental Design And Inference
#
# Mission: `p026-ds-l04-m01`
# Project anchor: `p026` `financial_volatility_surface_predictor`
#
# ## Guiding question
#
# What pattern is real, what prediction is useful, and how uncertain are we?
#
# ## Level intent
#
# Separate causal claims, correlations, and measurement bias.
#
# ## Mathematical spine
#
# $$P(A\mid B) = \frac{P(B\mid A)P(A)}{P(B)}, \qquad \hat{y} = f_\theta(x)$$

# %% [markdown]
# ## Competencies
#
# - Counterfactual reasoning
# - Confounding
# - Confidence intervals
#
# ## Method
#
# Make assumptions explicit and test whether the method still holds.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'data_science'
level = 'L04'
project_id = 'p026'
project_slug = 'financial_volatility_surface_predictor'
project_readme = Path('projects/financial_volatility_surface_predictor/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.financial_volatility_surface_predictor.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/financial_volatility_surface_predictor/README.md`](../../../projects/financial_volatility_surface_predictor/README.md)
# - Project notebook: `projects/financial_volatility_surface_predictor/notebooks/financial_volatility_surface_predictor.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
