# %% [markdown]
# # Data Analytics L01: Data Literacy
#
# This notebook teaches the level step by step. It assumes you are willing to slow down and define the idea before running project code.
#
# **Mission:** `p023-da-l01-m01`
# **Project anchor:** `p023` `experimental_reproducibility_analytics`
#
# ## Start from zero
#
# Read tables, units, categories, and variation before touching tools.
#
# Plain question: **What happened, why did it happen, and what decision should follow?**

# %% [markdown]
# ## 1. Vocabulary before tools
#
# Before using libraries, define the vocabulary.
#
# - `What is a row?`: write a one-sentence definition.
# - `What is a metric?`: point to where it appears in data, code, math, or system design.
# - `How do units distort interpretation?`: explain the risk if it is ignored.
#
# A useful rule: if you cannot explain the word with a tiny example, you are not ready to automate it.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'data_analytics'
level = 'L01'
project_id = 'p023'
project_slug = 'experimental_reproducibility_analytics'
project_readme = Path('projects') / project_slug / 'README.md'
project_notebook = 'projects/experimental_reproducibility_analytics/notebooks/experimental_reproducibility_analytics.ipynb'

{
    'repo_root': str(repo_root),
    'track': track,
    'level': level,
    'project_readme_exists': project_readme.exists(),
    'project_notebook': project_notebook,
}

# %% [markdown]
# ## 2. The core idea slowly
#
# This is the **Orientation** stage. Your job is to learn the vocabulary and objects before using tools.
#
# Do not rush to code. Name the thing being observed first.
#
# Every level in this repository follows the same reasoning chain:
#
# 1. Observation: what is directly visible?
# 2. Representation: how is it encoded?
# 3. Operation: what do we compute or transform?
# 4. Evidence: what output supports the claim?
# 5. Limitation: what could still be wrong?

# %% [markdown]
# ## 3. Mathematical spine
#
# \[\text{rate} = \frac{\Delta y}{\Delta t}, \qquad \bar{x} = \frac{1}{n}\sum_{i=1}^n x_i\]
#
# A rate compares change against time. An average compresses many observations into one representative value, but it can hide spread and outliers.
#
# At this level, do not try to memorize symbols. Translate each symbol into words and connect it to the project anchor.

# %%
learning_card = {
    'track': 'Data Analytics',
    'level': 'L01',
    'title': 'Data Literacy',
    'mission': 'p023-da-l01-m01',
    'project': 'experimental_reproducibility_analytics',
    'competencies': ['What is a row?', 'What is a metric?', 'How do units distort interpretation?'],
    'first_principle': 'analytics starts with a question, a population, an observation grain, and a metric definition',
}

for key, value in learning_card.items():
    print(f"{key}: {value}")

# %% [markdown]
# ## 4. Worked micro-example
#
# Imagine a table with one row per day. Before making a chart, ask what each row means, what metric is being counted, and whether how do units distort interpretation? could change the interpretation.
#
# Now answer:
#
# - What is the observation?
# - What is the representation?
# - What operation is being applied?
# - What output would count as evidence?
# - What limitation remains?

# %%
exercise = {
    'observation': '',
    'representation': '',
    'operation': '',
    'evidence': '',
    'limitation': '',
}

# Fill the strings above as notes while studying. Keeping them in a dict makes
# the reasoning explicit and easy to revise.
exercise

# %% [markdown]
# ## 5. Connect to the project
#
# Open the project README and notebook after you understand the vocabulary.
#
# Project README path:
#
# ```text
# projects/experimental_reproducibility_analytics/README.md
# ```
#
# Run command:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.experimental_reproducibility_analytics.src.pipeline
# ```
#
# Do not worry if the project feels more advanced than the level. Your task is to identify where this level's idea appears inside the project.

# %% [markdown]
# ## 6. Self-check without grades
#
# Mark yourself honestly:
#
# - `exploring`: I can repeat the words.
# - `practiced`: I can run this notebook and answer the prompts.
# - `demonstrated`: I can explain `Data Literacy` using `experimental_reproducibility_analytics`.
# - `extended`: I changed an assumption or proposed a stronger experiment.
#
# Before leaving the notebook, write one sentence for each competency: `What is a row?`, `What is a metric?`, and `How do units distort interpretation?`.
