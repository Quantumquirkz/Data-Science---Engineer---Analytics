# %% [markdown]
# # Scientific Computing L10: Reproducible Computational Science Capstone
#
# Mission: `p100-sc-l10-m01`
# Project anchor: `p100` `wind_turbine_failure_early_warning_system`
#
# ## Guiding question
#
# How do equations, numerical methods, and simulations become trustworthy computational evidence?
#
# ## Level intent
#
# Write and defend a computational study with numerical and scientific integrity.
#
# ## Mathematical spine
#
# $$\frac{d\mathbf{x}}{dt} = f(\mathbf{x}, t), \qquad \epsilon_h = \lVert x - x_h \rVert$$

# %% [markdown]
# ## Competencies
#
# - Reproducible experiments
# - Validation against theory
# - Scientific reporting
#
# ## Method
#
# Integrate the full track into a capstone-level system narrative.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'scientific_computing'
level = 'L10'
project_id = 'p100'
project_slug = 'wind_turbine_failure_early_warning_system'
project_readme = Path('projects/wind_turbine_failure_early_warning_system/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.wind_turbine_failure_early_warning_system.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/wind_turbine_failure_early_warning_system/README.md`](../../../projects/wind_turbine_failure_early_warning_system/README.md)
# - Project notebook: `projects/wind_turbine_failure_early_warning_system/notebooks/wind_turbine_failure_early_warning_system.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
