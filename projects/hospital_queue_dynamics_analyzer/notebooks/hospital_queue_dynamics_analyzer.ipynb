# %% [markdown]
# # Hospital Queue Dynamics Analyzer
#
# Model waiting times, resource bottlenecks, and patient flow in emergency departments.

# %%
from pathlib import Path
from projects.hospital_queue_dynamics_analyzer.src.pipeline import run_hospital_queue_dynamics_analyzer_pipeline
artifacts = run_hospital_queue_dynamics_analyzer_pipeline(Path('projects/hospital_queue_dynamics_analyzer'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
