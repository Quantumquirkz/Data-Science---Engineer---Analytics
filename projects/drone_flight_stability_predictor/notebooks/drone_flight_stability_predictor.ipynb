# %% [markdown]
# # Drone Flight Stability Predictor
#
# Predict unstable flight conditions from public drone flight logs, UAV benchmark datasets, or simulation telemetry.

# %%
from pathlib import Path
from projects.drone_flight_stability_predictor.src.pipeline import run_drone_flight_stability_predictor_pipeline
artifacts = run_drone_flight_stability_predictor_pipeline(Path('projects/drone_flight_stability_predictor'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
