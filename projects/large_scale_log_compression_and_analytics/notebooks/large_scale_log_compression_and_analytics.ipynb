# %% [markdown]
# # Large-Scale Log Compression and Analytics
#
# Build a pipeline to compress, index, and analyze massive machine-generated logs.

# %%
from pathlib import Path
from projects.large_scale_log_compression_and_analytics.src.pipeline import run_large_scale_log_compression_and_analytics_pipeline
artifacts = run_large_scale_log_compression_and_analytics_pipeline(Path('projects/large_scale_log_compression_and_analytics'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
