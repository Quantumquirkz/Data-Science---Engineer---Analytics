# %% [markdown]
# # Network Traffic Anomaly Detection
#
# Detect suspicious traffic spikes or abnormal communication patterns in large-scale network logs.

# %%
from pathlib import Path
from projects.network_traffic_anomaly_detection.src.pipeline import run_network_traffic_anomaly_detection_pipeline
artifacts = run_network_traffic_anomaly_detection_pipeline(Path('projects/network_traffic_anomaly_detection'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
