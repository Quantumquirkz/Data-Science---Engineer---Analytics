# %% [markdown]
# # Protein Folding Embedding Explorer
#
# Analyze high-dimensional protein representations and cluster structural patterns.

# %%
from pathlib import Path
from projects.protein_folding_embedding_explorer.src.pipeline import run_protein_folding_embedding_explorer_pipeline
artifacts = run_protein_folding_embedding_explorer_pipeline(Path('projects/protein_folding_embedding_explorer'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
