# %% [markdown]
# # Scientific Data Platform for Multi-Modal Experiments
#
# Design a mini platform to ingest, organize, query, and analyze heterogeneous experiment data at scale using public multi-modal scientific datasets.

# %%
from pathlib import Path
from projects.scientific_data_platform_for_multi_modal_experiments.src.pipeline import run_scientific_data_platform_for_multi_modal_experiments_pipeline
artifacts = run_scientific_data_platform_for_multi_modal_experiments_pipeline(Path('projects/scientific_data_platform_for_multi_modal_experiments'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
