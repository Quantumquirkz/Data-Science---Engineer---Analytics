# %% [markdown]
# # Large-Scale Sensor Missing Data Imputation
#
# Impute missing values across thousands of sensor streams with temporal and spatial structure using public IoT, weather, or industrial telemetry datasets.

# %%
from pathlib import Path
from projects.large_scale_sensor_missing_data_imputation.src.pipeline import run_large_scale_sensor_missing_data_imputation_pipeline
artifacts = run_large_scale_sensor_missing_data_imputation_pipeline(Path('projects/large_scale_sensor_missing_data_imputation'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
