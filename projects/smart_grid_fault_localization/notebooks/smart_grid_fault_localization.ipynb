# %% [markdown]
# # Smart Grid Fault Localization
#
# Localize likely faults in a smart grid using public power system benchmarks, simulated grids, and sparse telemetry logs.

# %%
from pathlib import Path
from projects.smart_grid_fault_localization.src.pipeline import run_smart_grid_fault_localization_pipeline
artifacts = run_smart_grid_fault_localization_pipeline(Path('projects/smart_grid_fault_localization'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
