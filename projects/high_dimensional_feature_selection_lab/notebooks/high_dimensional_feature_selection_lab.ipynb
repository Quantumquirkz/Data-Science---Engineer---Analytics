# %% [markdown]
# # High-Dimensional Feature Selection Lab
#
# Build and compare feature selection pipelines for wide datasets with many correlated variables.

# %%
from pathlib import Path
from projects.high_dimensional_feature_selection_lab.src.pipeline import run_high_dimensional_feature_selection_lab_pipeline
artifacts = run_high_dimensional_feature_selection_lab_pipeline(Path('projects/high_dimensional_feature_selection_lab'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
