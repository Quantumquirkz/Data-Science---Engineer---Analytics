# %% [markdown]
# # Data Analytics L08: Advanced Analytics Systems
#
# Mission: `p063-da-l08-m01`
# Project anchor: `p063` `protein_folding_embedding_explorer`
#
# ## Guiding question
#
# What happened, why did it happen, and what decision should follow?
#
# ## Level intent
#
# Build analytics surfaces that combine monitoring, drill-down, and reproducibility.
#
# ## Mathematical spine
#
# $$\text{rate} = \frac{\Delta y}{\Delta t}, \qquad \bar{x} = \frac{1}{n}\sum_{i=1}^n x_i$$

# %% [markdown]
# ## Competencies
#
# - Dashboard contracts
# - Semantic layers
# - Operational review loops
#
# ## Method
#
# Scale the method while preserving observability and interpretability.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'data_analytics'
level = 'L08'
project_id = 'p063'
project_slug = 'protein_folding_embedding_explorer'
project_readme = Path('projects/protein_folding_embedding_explorer/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.protein_folding_embedding_explorer.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/protein_folding_embedding_explorer/README.md`](../../../projects/protein_folding_embedding_explorer/README.md)
# - Project notebook: `projects/protein_folding_embedding_explorer/notebooks/protein_folding_embedding_explorer.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
