# %% [markdown]
# # Neuron Spike Train Modeling
#
# Model neural spike trains and infer activity patterns from electrophysiology data.

# %%
from pathlib import Path
from projects.neuron_spike_train_modeling.src.pipeline import run_neuron_spike_train_modeling_pipeline
artifacts = run_neuron_spike_train_modeling_pipeline(Path('projects/neuron_spike_train_modeling'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
