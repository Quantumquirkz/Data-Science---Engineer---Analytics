# %% [markdown]
# # Mechanical Resonance Identification
#
# Identify resonant frequencies in large collections of vibration signals.

# %%
from pathlib import Path
from projects.mechanical_resonance_identification.src.pipeline import run_mechanical_resonance_identification_pipeline
artifacts = run_mechanical_resonance_identification_pipeline(Path('projects/mechanical_resonance_identification'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
