# %% [markdown]
# # Financial Volatility Surface Predictor
#
# Model volatility surfaces from options market data.

# %%
from pathlib import Path
from projects.financial_volatility_surface_predictor.src.pipeline import run_financial_volatility_surface_predictor_pipeline
artifacts = run_financial_volatility_surface_predictor_pipeline(Path('projects/financial_volatility_surface_predictor'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
