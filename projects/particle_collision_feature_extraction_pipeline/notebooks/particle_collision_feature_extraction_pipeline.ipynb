# %% [markdown]
# # Particle Collision Feature Extraction Pipeline
#
# Build a scalable pipeline to preprocess and analyze high-energy collision event features.

# %%
from pathlib import Path
from projects.particle_collision_feature_extraction_pipeline.src.pipeline import run_particle_collision_feature_extraction_pipeline_pipeline
artifacts = run_particle_collision_feature_extraction_pipeline_pipeline(Path('projects/particle_collision_feature_extraction_pipeline'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
