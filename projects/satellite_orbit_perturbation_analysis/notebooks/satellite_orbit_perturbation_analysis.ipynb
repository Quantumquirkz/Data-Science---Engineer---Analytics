# %% [markdown]
# # Satellite Orbit Perturbation Analysis
#
# Analyze orbit perturbations from drag, gravity irregularities, and control corrections.

# %%
from pathlib import Path
from projects.satellite_orbit_perturbation_analysis.src.pipeline import run_satellite_orbit_perturbation_analysis_pipeline
artifacts = run_satellite_orbit_perturbation_analysis_pipeline(Path('projects/satellite_orbit_perturbation_analysis'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
