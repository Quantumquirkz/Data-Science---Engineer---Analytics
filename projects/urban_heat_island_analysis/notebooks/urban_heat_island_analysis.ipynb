# %% [markdown]
# # Urban Heat Island Analysis
#
# Quantify and predict urban heat island intensity from spatial and weather data.

# %%
from pathlib import Path
from projects.urban_heat_island_analysis.src.pipeline import run_urban_heat_island_analysis_pipeline
artifacts = run_urban_heat_island_analysis_pipeline(Path('projects/urban_heat_island_analysis'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
