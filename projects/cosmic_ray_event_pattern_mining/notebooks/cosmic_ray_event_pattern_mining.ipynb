# %% [markdown]
# # Cosmic Ray Event Pattern Mining
#
# Mine rare-event patterns from large astrophysics detector logs.

# %%
from pathlib import Path
from projects.cosmic_ray_event_pattern_mining.src.pipeline import run_cosmic_ray_event_pattern_mining_pipeline
artifacts = run_cosmic_ray_event_pattern_mining_pipeline(Path('projects/cosmic_ray_event_pattern_mining'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
