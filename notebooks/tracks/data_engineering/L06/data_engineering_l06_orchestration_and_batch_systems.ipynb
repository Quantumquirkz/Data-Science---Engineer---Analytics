# %% [markdown]
# # Data Engineering L06: Orchestration And Batch Systems
#
# Mission: `p060-de-l06-m01`
# Project anchor: `p060` `plasma_experiment_parameter_inference`
#
# ## Guiding question
#
# How does data move, stay valid, and remain trustworthy at scale?
#
# ## Level intent
#
# Sequence jobs, retries, and recovery paths for batch workflows.
#
# ## Mathematical spine
#
# $$\text{throughput} = \frac{\text{records processed}}{\text{time}}, \qquad \text{latency} = t_{out} - t_{in}$$

# %% [markdown]
# ## Competencies
#
# - DAG logic
# - Retries
# - Backfills
#
# ## Method
#
# Track uncertainty, variation, retries, or experimental lineage.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'data_engineering'
level = 'L06'
project_id = 'p060'
project_slug = 'plasma_experiment_parameter_inference'
project_readme = Path('projects/plasma_experiment_parameter_inference/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.plasma_experiment_parameter_inference.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/plasma_experiment_parameter_inference/README.md`](../../../projects/plasma_experiment_parameter_inference/README.md)
# - Project notebook: `projects/plasma_experiment_parameter_inference/notebooks/plasma_experiment_parameter_inference.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
