# %% [markdown]
# # Airplane Turbulence Pattern Mining
#
# Identify turbulence signatures from public flight telemetry archives and environmental conditions.

# %%
from pathlib import Path
from projects.airplane_turbulence_pattern_mining.src.pipeline import run_airplane_turbulence_pattern_mining_pipeline
artifacts = run_airplane_turbulence_pattern_mining_pipeline(Path('projects/airplane_turbulence_pattern_mining'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
