# %% [markdown]
# # Scientific Computing L09: Multiphysics, Surrogates, And Data Assimilation
#
# Mission: `p088-sc-l09-m01`
# Project anchor: `p088` `solar_irradiance_forecasting`
#
# ## Guiding question
#
# How do equations, numerical methods, and simulations become trustworthy computational evidence?
#
# ## Level intent
#
# Blend simulation, statistical updates, and learned surrogates.
#
# ## Mathematical spine
#
# $$\frac{d\mathbf{x}}{dt} = f(\mathbf{x}, t), \qquad \epsilon_h = \lVert x - x_h \rVert$$

# %% [markdown]
# ## Competencies
#
# - State estimation
# - Hybrid modeling
# - Assimilation loops
#
# ## Method
#
# Add governance, responsibility, numerical rigor, or scientific critique.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'scientific_computing'
level = 'L09'
project_id = 'p088'
project_slug = 'solar_irradiance_forecasting'
project_readme = Path('projects/solar_irradiance_forecasting/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.solar_irradiance_forecasting.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/solar_irradiance_forecasting/README.md`](../../../projects/solar_irradiance_forecasting/README.md)
# - Project notebook: `projects/solar_irradiance_forecasting/notebooks/solar_irradiance_forecasting.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
