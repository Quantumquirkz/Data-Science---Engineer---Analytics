# %% [markdown]
# # Adaptive Control for Energy Storage
#
# Develop a data-driven controller for charging and discharging battery storage systems using public battery benchmarks and simulated storage environments.

# %%
from pathlib import Path
from projects.adaptive_control_for_energy_storage.src.pipeline import run_adaptive_control_for_energy_storage_pipeline
artifacts = run_adaptive_control_for_energy_storage_pipeline(Path('projects/adaptive_control_for_energy_storage'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
