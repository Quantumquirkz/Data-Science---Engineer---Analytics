# %% [markdown]
# # Human Mobility Pattern Clustering
#
# Discover mobility archetypes from GPS, transport card, or mobile telemetry data.

# %%
from pathlib import Path
from projects.human_mobility_pattern_clustering.src.pipeline import run_human_mobility_pattern_clustering_pipeline
artifacts = run_human_mobility_pattern_clustering_pipeline(Path('projects/human_mobility_pattern_clustering'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
