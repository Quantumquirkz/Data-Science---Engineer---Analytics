# %% [markdown]
# # Atmospheric Pressure Anomaly Mapper
#
# Identify and visualize unusual pressure systems using large meteorological datasets.

# %%
from pathlib import Path
from projects.atmospheric_pressure_anomaly_mapper.src.pipeline import run_atmospheric_pressure_anomaly_mapper_pipeline
artifacts = run_atmospheric_pressure_anomaly_mapper_pipeline(Path('projects/atmospheric_pressure_anomaly_mapper'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
