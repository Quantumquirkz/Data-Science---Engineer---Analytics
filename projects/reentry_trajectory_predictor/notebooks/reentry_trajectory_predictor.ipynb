# %% [markdown]
# # Reentry Trajectory Predictor
#
# Predict reentry trajectories under uncertain atmospheric drag conditions.

# %%
from pathlib import Path
from projects.reentry_trajectory_predictor.src.pipeline import run_reentry_trajectory_predictor_pipeline
artifacts = run_reentry_trajectory_predictor_pipeline(Path('projects/reentry_trajectory_predictor'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
