# %% [markdown]
# # Data Science L05: Supervised Machine Learning
#
# Mission: `p028-ds-l05-m01`
# Project anchor: `p028` `fraud_detection_in_scientific_grant_data`
#
# ## Guiding question
#
# What pattern is real, what prediction is useful, and how uncertain are we?
#
# ## Level intent
#
# Build baselines, train models, and evaluate generalization.
#
# ## Mathematical spine
#
# $$P(A\mid B) = \frac{P(B\mid A)P(A)}{P(B)}, \qquad \hat{y} = f_\theta(x)$$

# %% [markdown]
# ## Competencies
#
# - Feature-target split
# - Metrics
# - Overfitting
#
# ## Method
#
# Build a baseline artifact and compare it against a stronger alternative.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'data_science'
level = 'L05'
project_id = 'p028'
project_slug = 'fraud_detection_in_scientific_grant_data'
project_readme = Path('projects/fraud_detection_in_scientific_grant_data/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.fraud_detection_in_scientific_grant_data.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/fraud_detection_in_scientific_grant_data/README.md`](../../../projects/fraud_detection_in_scientific_grant_data/README.md)
# - Project notebook: `projects/fraud_detection_in_scientific_grant_data/notebooks/fraud_detection_in_scientific_grant_data.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
