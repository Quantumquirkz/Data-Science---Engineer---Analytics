# %% [markdown]
# # Scientific Computing L06: Monte Carlo And Stochastic Processes
#
# Mission: `p044-sc-l06-m01`
# Project anchor: `p044` `magnetic_field_sensor_reconstruction`
#
# ## Guiding question
#
# How do equations, numerical methods, and simulations become trustworthy computational evidence?
#
# ## Level intent
#
# Represent randomness, ensembles, and uncertainty propagation.
#
# ## Mathematical spine
#
# $$\frac{d\mathbf{x}}{dt} = f(\mathbf{x}, t), \qquad \epsilon_h = \lVert x - x_h \rVert$$

# %% [markdown]
# ## Competencies
#
# - Sampling
# - Variance reduction
# - Random walks
#
# ## Method
#
# Track uncertainty, variation, retries, or experimental lineage.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'scientific_computing'
level = 'L06'
project_id = 'p044'
project_slug = 'magnetic_field_sensor_reconstruction'
project_readme = Path('projects/magnetic_field_sensor_reconstruction/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.magnetic_field_sensor_reconstruction.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/magnetic_field_sensor_reconstruction/README.md`](../../../projects/magnetic_field_sensor_reconstruction/README.md)
# - Project notebook: `projects/magnetic_field_sensor_reconstruction/notebooks/magnetic_field_sensor_reconstruction.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
