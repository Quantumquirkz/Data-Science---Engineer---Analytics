# %% [markdown]
# # Experimental Reproducibility Analytics
#
# Analyze repeated experiments to quantify reproducibility and hidden variability using open scientific datasets with repeated trials.

# %%
from pathlib import Path
from projects.experimental_reproducibility_analytics.src.pipeline import run_experimental_reproducibility_analytics_pipeline
artifacts = run_experimental_reproducibility_analytics_pipeline(Path('projects/experimental_reproducibility_analytics'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
