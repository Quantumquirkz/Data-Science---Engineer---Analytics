# %% [markdown]
# # Fluid Flow Surrogate Model
#
# Train a machine learning model to approximate outputs of expensive fluid dynamics simulations.

# %%
from pathlib import Path
from projects.fluid_flow_surrogate_model.src.pipeline import run_fluid_flow_surrogate_model_pipeline
artifacts = run_fluid_flow_surrogate_model_pipeline(Path('projects/fluid_flow_surrogate_model'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
