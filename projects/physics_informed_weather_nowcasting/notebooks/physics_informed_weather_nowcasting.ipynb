# %% [markdown]
# # Physics-Informed Weather Nowcasting
#
# Combine short-term radar observations with physical priors to improve nowcasting using open meteorological radar datasets.

# %%
from pathlib import Path
from projects.physics_informed_weather_nowcasting.src.pipeline import run_physics_informed_weather_nowcasting_pipeline
artifacts = run_physics_informed_weather_nowcasting_pipeline(Path('projects/physics_informed_weather_nowcasting'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
