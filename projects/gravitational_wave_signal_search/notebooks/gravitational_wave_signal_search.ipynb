# %% [markdown]
# # Gravitational Wave Signal Search
#
# Search for faint gravitational wave-like patterns in noisy time series.

# %%
from pathlib import Path
from projects.gravitational_wave_signal_search.src.pipeline import run_gravitational_wave_signal_search_pipeline
artifacts = run_gravitational_wave_signal_search_pipeline(Path('projects/gravitational_wave_signal_search'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
