# %% [markdown]
# # Weather Front Boundary Detection
#
# Detect moving weather fronts from gridded atmospheric data.

# %%
from pathlib import Path
from projects.weather_front_boundary_detection.src.pipeline import run_weather_front_boundary_detection_pipeline
artifacts = run_weather_front_boundary_detection_pipeline(Path('projects/weather_front_boundary_detection'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
