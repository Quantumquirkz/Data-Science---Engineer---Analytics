# %% [markdown]
# # Data Science L09: Advanced ML And Scientific Modeling
#
# Mission: `p082-ds-l09-m01`
# Project anchor: `p082` `sensor_drift_detection`
#
# ## Guiding question
#
# What pattern is real, what prediction is useful, and how uncertain are we?
#
# ## Level intent
#
# Bridge predictive modeling with domain-governed physical or biological structure.
#
# ## Mathematical spine
#
# $$P(A\mid B) = \frac{P(B\mid A)P(A)}{P(B)}, \qquad \hat{y} = f_\theta(x)$$

# %% [markdown]
# ## Competencies
#
# - Hybrid models
# - Constraint-aware learning
# - Error decomposition
#
# ## Method
#
# Add governance, responsibility, numerical rigor, or scientific critique.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'data_science'
level = 'L09'
project_id = 'p082'
project_slug = 'sensor_drift_detection'
project_readme = Path('projects/sensor_drift_detection/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.sensor_drift_detection.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/sensor_drift_detection/README.md`](../../../projects/sensor_drift_detection/README.md)
# - Project notebook: `projects/sensor_drift_detection/notebooks/sensor_drift_detection.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
