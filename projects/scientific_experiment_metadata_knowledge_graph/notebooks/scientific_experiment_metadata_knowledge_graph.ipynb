# %% [markdown]
# # Scientific Experiment Metadata Knowledge Graph
#
# Build a knowledge graph linking experiments, instruments, variables, and outcomes from published papers, open metadata, and public repositories.

# %%
from pathlib import Path
from projects.scientific_experiment_metadata_knowledge_graph.src.pipeline import run_scientific_experiment_metadata_knowledge_graph_pipeline
artifacts = run_scientific_experiment_metadata_knowledge_graph_pipeline(Path('projects/scientific_experiment_metadata_knowledge_graph'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
