# %% [markdown]
# # Scientific Computing L08: High-Performance Computing
#
# Mission: `p067-sc-l08-m01`
# Project anchor: `p067` `real_time_manufacturing_yield_dashboard`
#
# ## Guiding question
#
# How do equations, numerical methods, and simulations become trustworthy computational evidence?
#
# ## Level intent
#
# Reason about memory, vectorization, and parallel workloads for simulation.
#
# ## Mathematical spine
#
# $$\frac{d\mathbf{x}}{dt} = f(\mathbf{x}, t), \qquad \epsilon_h = \lVert x - x_h \rVert$$

# %% [markdown]
# ## Competencies
#
# - Memory bandwidth
# - Parallel decomposition
# - Profiling
#
# ## Method
#
# Scale the method while preserving observability and interpretability.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'scientific_computing'
level = 'L08'
project_id = 'p067'
project_slug = 'real_time_manufacturing_yield_dashboard'
project_readme = Path('projects/real_time_manufacturing_yield_dashboard/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.real_time_manufacturing_yield_dashboard.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/real_time_manufacturing_yield_dashboard/README.md`](../../../projects/real_time_manufacturing_yield_dashboard/README.md)
# - Project notebook: `projects/real_time_manufacturing_yield_dashboard/notebooks/real_time_manufacturing_yield_dashboard.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
