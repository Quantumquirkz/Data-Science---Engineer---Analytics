# %% [markdown]
# # Large-Scale Recommendation for Learning Paths
#
# Recommend educational or research paths based on content similarity and user progress.

# %%
from pathlib import Path
from projects.large_scale_recommendation_for_learning_paths.src.pipeline import run_large_scale_recommendation_for_learning_paths_pipeline
artifacts = run_large_scale_recommendation_for_learning_paths_pipeline(Path('projects/large_scale_recommendation_for_learning_paths'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
