# %% [markdown]
# # Magnetic Field Sensor Reconstruction
#
# Reconstruct missing or corrupted magnetic field measurements from open magnetic observatory records or simulated distributed sensor data.

# %%
from pathlib import Path
from projects.magnetic_field_sensor_reconstruction.src.pipeline import run_magnetic_field_sensor_reconstruction_pipeline
artifacts = run_magnetic_field_sensor_reconstruction_pipeline(Path('projects/magnetic_field_sensor_reconstruction'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
