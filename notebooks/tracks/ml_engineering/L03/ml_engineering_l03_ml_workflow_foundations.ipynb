# %% [markdown]
# # ML Engineering L03: ML Workflow Foundations
#
# This notebook teaches the level step by step. It assumes you are willing to slow down and define the idea before running project code.
#
# **Mission:** `p041-mle-l03-m01`
# **Project anchor:** `p041` `large_scale_recommendation_for_learning_paths`
#
# ## Start from zero
#
# Separate data loading, feature logic, training, and evaluation cleanly.
#
# Plain question: **How does a model become a reliable, reproducible, inspectable software system?**

# %% [markdown]
# ## 1. Vocabulary before tools
#
# Before using libraries, define the vocabulary.
#
# - `Pipeline stages`: write a one-sentence definition.
# - `Artifact naming`: point to where it appears in data, code, math, or system design.
# - `Re-run safety`: explain the risk if it is ignored.
#
# A useful rule: if you cannot explain the word with a tiny example, you are not ready to automate it.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'ml_engineering'
level = 'L03'
project_id = 'p041'
project_slug = 'large_scale_recommendation_for_learning_paths'
project_readme = Path('projects') / project_slug / 'README.md'
project_notebook = 'projects/large_scale_recommendation_for_learning_paths/notebooks/large_scale_recommendation_for_learning_paths.ipynb'

{
    'repo_root': str(repo_root),
    'track': track,
    'level': level,
    'project_readme_exists': project_readme.exists(),
    'project_notebook': project_notebook,
}

# %% [markdown]
# ## 2. The core idea slowly
#
# This is the **Structure** stage. Your job is to recognize patterns, schemas, distributions, workflows, or mathematical forms.
#
# Structure is what lets you compare cases fairly.
#
# Every level in this repository follows the same reasoning chain:
#
# 1. Observation: what is directly visible?
# 2. Representation: how is it encoded?
# 3. Operation: what do we compute or transform?
# 4. Evidence: what output supports the claim?
# 5. Limitation: what could still be wrong?

# %% [markdown]
# ## 3. Mathematical spine
#
# \[\mathcal{L}(\theta) = \frac{1}{n}\sum_{i=1}^n \ell(f_\theta(x_i), y_i), \qquad \text{SLO}=\{\text{latency},\text{availability},\text{quality}\}\]
#
# The loss summarizes model error during training. Service objectives describe the operational promises the system must keep after training.
#
# At this level, do not try to memorize symbols. Translate each symbol into words and connect it to the project anchor.

# %%
learning_card = {
    'track': 'ML Engineering',
    'level': 'L03',
    'title': 'ML Workflow Foundations',
    'mission': 'p041-mle-l03-m01',
    'project': 'large_scale_recommendation_for_learning_paths',
    'competencies': ['Pipeline stages', 'Artifact naming', 'Re-run safety'],
    'first_principle': 'ML engineering starts when a model becomes part of a system that other people or processes depend on',
}

for key, value in learning_card.items():
    print(f"{key}: {value}")

# %% [markdown]
# ## 4. Worked micro-example
#
# Imagine a trained model inside an app. You need to know where the package boundary is, how to call it, and how re-run safety affects repeated runs.
#
# Now answer:
#
# - What is the observation?
# - What is the representation?
# - What operation is being applied?
# - What output would count as evidence?
# - What limitation remains?

# %%
exercise = {
    'observation': '',
    'representation': '',
    'operation': '',
    'evidence': '',
    'limitation': '',
}

# Fill the strings above as notes while studying. Keeping them in a dict makes
# the reasoning explicit and easy to revise.
exercise

# %% [markdown]
# ## 5. Connect to the project
#
# Open the project README and notebook after you understand the vocabulary.
#
# Project README path:
#
# ```text
# projects/large_scale_recommendation_for_learning_paths/README.md
# ```
#
# Run command:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.large_scale_recommendation_for_learning_paths.src.pipeline
# ```
#
# Do not worry if the project feels more advanced than the level. Your task is to identify where this level's idea appears inside the project.

# %% [markdown]
# ## 6. Self-check without grades
#
# Mark yourself honestly:
#
# - `exploring`: I can repeat the words.
# - `practiced`: I can run this notebook and answer the prompts.
# - `demonstrated`: I can explain `ML Workflow Foundations` using `large_scale_recommendation_for_learning_paths`.
# - `extended`: I changed an assumption or proposed a stronger experiment.
#
# Before leaving the notebook, write one sentence for each competency: `Pipeline stages`, `Artifact naming`, and `Re-run safety`.
