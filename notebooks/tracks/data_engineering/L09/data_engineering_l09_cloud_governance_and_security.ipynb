# %% [markdown]
# # Data Engineering L09: Cloud Governance And Security
#
# Mission: `p078-de-l09-m01`
# Project anchor: `p078` `scientific_image_segmentation_benchmark`
#
# ## Guiding question
#
# How does data move, stay valid, and remain trustworthy at scale?
#
# ## Level intent
#
# Treat access control, cost, lineage, and compliance as core architecture.
#
# ## Mathematical spine
#
# $$\text{throughput} = \frac{\text{records processed}}{\text{time}}, \qquad \text{latency} = t_{out} - t_{in}$$

# %% [markdown]
# ## Competencies
#
# - IAM basics
# - Retention policy
# - Data classification
#
# ## Method
#
# Add governance, responsibility, numerical rigor, or scientific critique.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'data_engineering'
level = 'L09'
project_id = 'p078'
project_slug = 'scientific_image_segmentation_benchmark'
project_readme = Path('projects/scientific_image_segmentation_benchmark/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.scientific_image_segmentation_benchmark.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/scientific_image_segmentation_benchmark/README.md`](../../../projects/scientific_image_segmentation_benchmark/README.md)
# - Project notebook: `projects/scientific_image_segmentation_benchmark/notebooks/scientific_image_segmentation_benchmark.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
