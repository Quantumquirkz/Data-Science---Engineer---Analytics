# %% [markdown]
# # Energy Consumption Segmentation
#
# Cluster households or facilities based on their energy-use signatures.

# %%
from pathlib import Path
from projects.energy_consumption_segmentation.src.pipeline import run_energy_consumption_segmentation_pipeline
artifacts = run_energy_consumption_segmentation_pipeline(Path('projects/energy_consumption_segmentation'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
