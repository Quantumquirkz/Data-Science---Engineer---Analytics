# %% [markdown]
# # ML Engineering L10: Production ML Platform Capstone
#
# Mission: `p099-mle-l10-m01`
# Project anchor: `p099` `wildfire_spread_prediction`
#
# ## Guiding question
#
# How does a model become a reliable, reproducible, inspectable software system?
#
# ## Level intent
#
# Present a production-grade ML service architecture from training to monitoring.
#
# ## Mathematical spine
#
# $$\mathcal{L}(\theta) = \frac{1}{n}\sum_{i=1}^n \ell\left(f_\theta(x_i), y_i\right), \qquad \text{SLO}=\{\text{latency},\text{availability},\text{quality}\}$$

# %% [markdown]
# ## Competencies
#
# - Service boundaries
# - Risk controls
# - Incident response
#
# ## Method
#
# Integrate the full track into a capstone-level system narrative.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'ml_engineering'
level = 'L10'
project_id = 'p099'
project_slug = 'wildfire_spread_prediction'
project_readme = Path('projects/wildfire_spread_prediction/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.wildfire_spread_prediction.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/wildfire_spread_prediction/README.md`](../../../projects/wildfire_spread_prediction/README.md)
# - Project notebook: `projects/wildfire_spread_prediction/notebooks/wildfire_spread_prediction.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
