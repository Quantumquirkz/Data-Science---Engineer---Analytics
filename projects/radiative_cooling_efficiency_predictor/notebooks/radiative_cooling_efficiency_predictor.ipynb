# %% [markdown]
# # Radiative Cooling Efficiency Predictor
#
# Model cooling performance of materials under varying thermal and radiative conditions using published experimental datasets or simulation outputs.

# %%
from pathlib import Path
from projects.radiative_cooling_efficiency_predictor.src.pipeline import run_radiative_cooling_efficiency_predictor_pipeline
artifacts = run_radiative_cooling_efficiency_predictor_pipeline(Path('projects/radiative_cooling_efficiency_predictor'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
