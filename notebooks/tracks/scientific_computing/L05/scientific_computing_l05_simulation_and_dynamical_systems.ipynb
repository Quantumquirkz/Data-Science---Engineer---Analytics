# %% [markdown]
# # Scientific Computing L05: Simulation And Dynamical Systems
#
# Mission: `p030-sc-l05-m01`
# Project anchor: `p030` `gravitational_wave_signal_search`
#
# ## Guiding question
#
# How do equations, numerical methods, and simulations become trustworthy computational evidence?
#
# ## Level intent
#
# Model interacting systems and interpret phase behavior.
#
# ## Mathematical spine
#
# $$\frac{d\mathbf{x}}{dt} = f(\mathbf{x}, t), \qquad \epsilon_h = \lVert x - x_h \rVert$$

# %% [markdown]
# ## Competencies
#
# - State evolution
# - Conservation laws
# - Phase portraits
#
# ## Method
#
# Build a baseline artifact and compare it against a stronger alternative.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'scientific_computing'
level = 'L05'
project_id = 'p030'
project_slug = 'gravitational_wave_signal_search'
project_readme = Path('projects/gravitational_wave_signal_search/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.gravitational_wave_signal_search.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/gravitational_wave_signal_search/README.md`](../../../projects/gravitational_wave_signal_search/README.md)
# - Project notebook: `projects/gravitational_wave_signal_search/notebooks/gravitational_wave_signal_search.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
