# %% [markdown]
# # Scientific Computing L04: Differential Equations And Numerical Error
#
# Mission: `p027-sc-l04-m01`
# Project anchor: `p027` `fluid_flow_surrogate_model`
#
# ## Guiding question
#
# How do equations, numerical methods, and simulations become trustworthy computational evidence?
#
# ## Level intent
#
# Solve evolving systems while tracking discretization error.
#
# ## Mathematical spine
#
# $$\frac{d\mathbf{x}}{dt} = f(\mathbf{x}, t), \qquad \epsilon_h = \lVert x - x_h \rVert$$

# %% [markdown]
# ## Competencies
#
# - Euler stepping
# - Stability
# - Convergence
#
# ## Method
#
# Make assumptions explicit and test whether the method still holds.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'scientific_computing'
level = 'L04'
project_id = 'p027'
project_slug = 'fluid_flow_surrogate_model'
project_readme = Path('projects/fluid_flow_surrogate_model/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.fluid_flow_surrogate_model.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/fluid_flow_surrogate_model/README.md`](../../../projects/fluid_flow_surrogate_model/README.md)
# - Project notebook: `projects/fluid_flow_surrogate_model/notebooks/fluid_flow_surrogate_model.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
