# %% [markdown]
# # Data Analytics L10: Analytics Strategy Capstone
#
# Mission: `p097-da-l10-m01`
# Project anchor: `p097` `warehouse_robotics_path_optimization`
#
# ## Guiding question
#
# What happened, why did it happen, and what decision should follow?
#
# ## Level intent
#
# Defend an end-to-end analytics system as if it were serving a real organization.
#
# ## Mathematical spine
#
# $$\text{rate} = \frac{\Delta y}{\Delta t}, \qquad \bar{x} = \frac{1}{n}\sum_{i=1}^n x_i$$

# %% [markdown]
# ## Competencies
#
# - Executive communication
# - Decision memos
# - Roadmap prioritization
#
# ## Method
#
# Integrate the full track into a capstone-level system narrative.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'data_analytics'
level = 'L10'
project_id = 'p097'
project_slug = 'warehouse_robotics_path_optimization'
project_readme = Path('projects/warehouse_robotics_path_optimization/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.warehouse_robotics_path_optimization.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/warehouse_robotics_path_optimization/README.md`](../../../projects/warehouse_robotics_path_optimization/README.md)
# - Project notebook: `projects/warehouse_robotics_path_optimization/notebooks/warehouse_robotics_path_optimization.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
