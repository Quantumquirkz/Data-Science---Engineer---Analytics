# %% [markdown]
# # Financial Regime Change Detector
#
# Detect transitions between market regimes using multivariate market signals.

# %%
from pathlib import Path
from projects.financial_regime_change_detector.src.pipeline import run_financial_regime_change_detector_pipeline
artifacts = run_financial_regime_change_detector_pipeline(Path('projects/financial_regime_change_detector'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
