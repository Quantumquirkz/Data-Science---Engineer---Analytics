# %% [markdown]
# # Data Engineering L01: Computing Foundations
#
# Mission: `p039-de-l01-m01`
# Project anchor: `p039` `large_scale_astronomy_catalog_linker`
#
# ## Guiding question
#
# How does data move, stay valid, and remain trustworthy at scale?
#
# ## Level intent
#
# Understand files, directories, reproducible environments, and command execution as system primitives.
#
# ## Mathematical spine
#
# $$\text{throughput} = \frac{\text{records processed}}{\text{time}}, \qquad \text{latency} = t_{out} - t_{in}$$

# %% [markdown]
# ## Competencies
#
# - Filesystem mental model
# - Environment reproducibility
# - Failure surfaces
#
# ## Method
#
# Define the objects of study before using tooling.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'data_engineering'
level = 'L01'
project_id = 'p039'
project_slug = 'large_scale_astronomy_catalog_linker'
project_readme = Path('projects/large_scale_astronomy_catalog_linker/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.large_scale_astronomy_catalog_linker.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/large_scale_astronomy_catalog_linker/README.md`](../../../projects/large_scale_astronomy_catalog_linker/README.md)
# - Project notebook: `projects/large_scale_astronomy_catalog_linker/notebooks/large_scale_astronomy_catalog_linker.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
