# %% [markdown]
# # Data Analytics L03: Descriptive Analytics
#
# Mission: `p019-da-l03-m01`
# Project anchor: `p019` `energy_market_scenario_generator`
#
# ## Guiding question
#
# What happened, why did it happen, and what decision should follow?
#
# ## Level intent
#
# Summarize central tendency, spread, segmentation, and anomalies.
#
# ## Mathematical spine
#
# $$\text{rate} = \frac{\Delta y}{\Delta t}, \qquad \bar{x} = \frac{1}{n}\sum_{i=1}^n x_i$$

# %% [markdown]
# ## Competencies
#
# - Distributions
# - Percentiles
# - Cohorts
#
# ## Method
#
# Reason about structure: distributions, schemas, workflows, or equations.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'data_analytics'
level = 'L03'
project_id = 'p019'
project_slug = 'energy_market_scenario_generator'
project_readme = Path('projects/energy_market_scenario_generator/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.energy_market_scenario_generator.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/energy_market_scenario_generator/README.md`](../../../projects/energy_market_scenario_generator/README.md)
# - Project notebook: `projects/energy_market_scenario_generator/notebooks/energy_market_scenario_generator.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
