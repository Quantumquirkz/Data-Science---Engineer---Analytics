# %% [markdown]
# # Human Gait Stability Analysis
#
# Analyze gait dynamics to identify instability or recovery trends from public gait and motion-capture datasets.

# %%
from pathlib import Path
from projects.human_gait_stability_analysis.src.pipeline import run_human_gait_stability_analysis_pipeline
artifacts = run_human_gait_stability_analysis_pipeline(Path('projects/human_gait_stability_analysis'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
