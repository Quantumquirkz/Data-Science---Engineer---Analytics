# %% [markdown]
# # Data Science L07: Time Series And Forecasting
#
# This notebook teaches the level step by step. It assumes you are willing to slow down and define the idea before running project code.
#
# **Mission:** `p034-ds-l07-m01`
# **Project anchor:** `p034` `human_activity_recognition_from_wearables`
#
# ## Start from zero
#
# Model sequential dependence and forecast under temporal leakage constraints.
#
# Plain question: **What pattern is real, what prediction is useful, and how uncertain are we?**

# %% [markdown]
# ## 1. Vocabulary before tools
#
# Before using libraries, define the vocabulary.
#
# - `Lag structure`: write a one-sentence definition.
# - `Backtesting`: point to where it appears in data, code, math, or system design.
# - `Regime shifts`: explain the risk if it is ignored.
#
# A useful rule: if you cannot explain the word with a tiny example, you are not ready to automate it.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'data_science'
level = 'L07'
project_id = 'p034'
project_slug = 'human_activity_recognition_from_wearables'
project_readme = Path('projects') / project_slug / 'README.md'
project_notebook = 'projects/human_activity_recognition_from_wearables/notebooks/human_activity_recognition_from_wearables.ipynb'

{
    'repo_root': str(repo_root),
    'track': track,
    'level': level,
    'project_readme_exists': project_readme.exists(),
    'project_notebook': project_notebook,
}

# %% [markdown]
# ## 2. The core idea slowly
#
# This is the **Time And Change** stage. Your job is to work with sequences, automation, forecasting, deployment, or inverse reasoning.
#
# Many systems fail because the world changes after the first successful run.
#
# Every level in this repository follows the same reasoning chain:
#
# 1. Observation: what is directly visible?
# 2. Representation: how is it encoded?
# 3. Operation: what do we compute or transform?
# 4. Evidence: what output supports the claim?
# 5. Limitation: what could still be wrong?

# %% [markdown]
# ## 3. Mathematical spine
#
# \[P(A\mid B) = \frac{P(B\mid A)P(A)}{P(B)}, \qquad \hat{y} = f_\theta(x)\]
#
# Bayes' rule updates belief when evidence arrives. A prediction function maps inputs x to an estimated output, but only under assumptions learned from data.
#
# At this level, do not try to memorize symbols. Translate each symbol into words and connect it to the project anchor.

# %%
learning_card = {
    'track': 'Data Science',
    'level': 'L07',
    'title': 'Time Series And Forecasting',
    'mission': 'p034-ds-l07-m01',
    'project': 'human_activity_recognition_from_wearables',
    'competencies': ['Lag structure', 'Backtesting', 'Regime shifts'],
    'first_principle': 'data science starts with observations, hypotheses, assumptions, and a testable definition of success',
}

for key, value in learning_card.items():
    print(f"{key}: {value}")

# %% [markdown]
# ## 4. Worked micro-example
#
# Imagine predicting tomorrow's air quality. You first define the target, then decide which weather features are available before tomorrow, and finally check whether regime shifts could leak future information.
#
# Now answer:
#
# - What is the observation?
# - What is the representation?
# - What operation is being applied?
# - What output would count as evidence?
# - What limitation remains?

# %%
exercise = {
    'observation': '',
    'representation': '',
    'operation': '',
    'evidence': '',
    'limitation': '',
}

# Fill the strings above as notes while studying. Keeping them in a dict makes
# the reasoning explicit and easy to revise.
exercise

# %% [markdown]
# ## 5. Connect to the project
#
# Open the project README and notebook after you understand the vocabulary.
#
# Project README path:
#
# ```text
# projects/human_activity_recognition_from_wearables/README.md
# ```
#
# Run command:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.human_activity_recognition_from_wearables.src.pipeline
# ```
#
# Do not worry if the project feels more advanced than the level. Your task is to identify where this level's idea appears inside the project.

# %% [markdown]
# ## 6. Self-check without grades
#
# Mark yourself honestly:
#
# - `exploring`: I can repeat the words.
# - `practiced`: I can run this notebook and answer the prompts.
# - `demonstrated`: I can explain `Time Series And Forecasting` using `human_activity_recognition_from_wearables`.
# - `extended`: I changed an assumption or proposed a stronger experiment.
#
# Before leaving the notebook, write one sentence for each competency: `Lag structure`, `Backtesting`, and `Regime shifts`.
