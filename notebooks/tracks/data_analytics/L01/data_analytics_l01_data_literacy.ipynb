# %% [markdown]
# # Data Analytics L01: Data Literacy
#
# Mission: `p023-da-l01-m01`
# Project anchor: `p023` `experimental_reproducibility_analytics`
#
# ## Guiding question
#
# What happened, why did it happen, and what decision should follow?
#
# ## Level intent
#
# Read tables, units, categories, and variation before touching tools.
#
# ## Mathematical spine
#
# $$\text{rate} = \frac{\Delta y}{\Delta t}, \qquad \bar{x} = \frac{1}{n}\sum_{i=1}^n x_i$$

# %% [markdown]
# ## Competencies
#
# - What is a row?
# - What is a metric?
# - How do units distort interpretation?
#
# ## Method
#
# Define the objects of study before using tooling.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'data_analytics'
level = 'L01'
project_id = 'p023'
project_slug = 'experimental_reproducibility_analytics'
project_readme = Path('projects/experimental_reproducibility_analytics/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.experimental_reproducibility_analytics.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/experimental_reproducibility_analytics/README.md`](../../../projects/experimental_reproducibility_analytics/README.md)
# - Project notebook: `projects/experimental_reproducibility_analytics/notebooks/experimental_reproducibility_analytics.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
