# %% [markdown]
# # Epidemiological Spread Simulation
#
# Model and analyze disease spread using compartmental and network approaches.

# %%
from pathlib import Path
from projects.epidemiological_spread_simulation.src.pipeline import run_epidemiological_spread_simulation_pipeline
artifacts = run_epidemiological_spread_simulation_pipeline(Path('projects/epidemiological_spread_simulation'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
