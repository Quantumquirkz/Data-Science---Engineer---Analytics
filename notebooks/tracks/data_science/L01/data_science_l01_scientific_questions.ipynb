# %% [markdown]
# # Data Science L01: Scientific Questions
#
# Mission: `p002-ds-l01-m01`
# Project anchor: `p002` `air_quality_hotspot_prediction`
#
# ## Guiding question
#
# What pattern is real, what prediction is useful, and how uncertain are we?
#
# ## Level intent
#
# Frame data work as questions, observations, hypotheses, and measurable targets.
#
# ## Mathematical spine
#
# $$P(A\mid B) = \frac{P(B\mid A)P(A)}{P(B)}, \qquad \hat{y} = f_\theta(x)$$

# %% [markdown]
# ## Competencies
#
# - Question formulation
# - Observational units
# - Target leakage intuition
#
# ## Method
#
# Define the objects of study before using tooling.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'data_science'
level = 'L01'
project_id = 'p002'
project_slug = 'air_quality_hotspot_prediction'
project_readme = Path('projects/air_quality_hotspot_prediction/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.air_quality_hotspot_prediction.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/air_quality_hotspot_prediction/README.md`](../../../projects/air_quality_hotspot_prediction/README.md)
# - Project notebook: `projects/air_quality_hotspot_prediction/notebooks/air_quality_hotspot_prediction.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
