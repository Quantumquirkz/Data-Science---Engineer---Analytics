# %% [markdown]
# # Data Science L03: Probability And Statistics
#
# Mission: `p025-ds-l03-m01`
# Project anchor: `p025` `financial_regime_change_detector`
#
# ## Guiding question
#
# What pattern is real, what prediction is useful, and how uncertain are we?
#
# ## Level intent
#
# Quantify variation, uncertainty, and sampling error.
#
# ## Mathematical spine
#
# $$P(A\mid B) = \frac{P(B\mid A)P(A)}{P(B)}, \qquad \hat{y} = f_\theta(x)$$

# %% [markdown]
# ## Competencies
#
# - Random variables
# - Distributions
# - Estimation
#
# ## Method
#
# Reason about structure: distributions, schemas, workflows, or equations.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'data_science'
level = 'L03'
project_id = 'p025'
project_slug = 'financial_regime_change_detector'
project_readme = Path('projects/financial_regime_change_detector/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.financial_regime_change_detector.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/financial_regime_change_detector/README.md`](../../../projects/financial_regime_change_detector/README.md)
# - Project notebook: `projects/financial_regime_change_detector/notebooks/financial_regime_change_detector.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
