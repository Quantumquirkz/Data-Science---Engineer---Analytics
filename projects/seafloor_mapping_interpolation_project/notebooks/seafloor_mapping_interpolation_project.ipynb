# %% [markdown]
# # Seafloor Mapping Interpolation Project
#
# Reconstruct seafloor depth maps from public bathymetry datasets and sparse sonar benchmark measurements.

# %%
from pathlib import Path
from projects.seafloor_mapping_interpolation_project.src.pipeline import run_seafloor_mapping_interpolation_project_pipeline
artifacts = run_seafloor_mapping_interpolation_project_pipeline(Path('projects/seafloor_mapping_interpolation_project'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
