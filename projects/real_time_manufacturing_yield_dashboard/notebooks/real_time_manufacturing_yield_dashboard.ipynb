# %% [markdown]
# # Real-Time Manufacturing Yield Dashboard
#
# Build a dashboard for monitoring production yield, anomalies, and process drift.

# %%
from pathlib import Path
from projects.real_time_manufacturing_yield_dashboard.src.pipeline import run_real_time_manufacturing_yield_dashboard_pipeline
artifacts = run_real_time_manufacturing_yield_dashboard_pipeline(Path('projects/real_time_manufacturing_yield_dashboard'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
