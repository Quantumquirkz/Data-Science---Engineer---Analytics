# %% [markdown]
# # Supply Chain as a Dynamic Network
#
# Model supply chain disruptions and flow optimization under uncertainty.

# %%
from pathlib import Path
from projects.supply_chain_as_a_dynamic_network.src.pipeline import run_supply_chain_as_a_dynamic_network_pipeline
artifacts = run_supply_chain_as_a_dynamic_network_pipeline(Path('projects/supply_chain_as_a_dynamic_network'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
