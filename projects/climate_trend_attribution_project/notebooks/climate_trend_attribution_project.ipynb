# %% [markdown]
# # Climate Trend Attribution Project
#
# Separate long-term climate trends from seasonal and random effects in large datasets.

# %%
from pathlib import Path
from projects.climate_trend_attribution_project.src.pipeline import run_climate_trend_attribution_project_pipeline
artifacts = run_climate_trend_attribution_project_pipeline(Path('projects/climate_trend_attribution_project'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
