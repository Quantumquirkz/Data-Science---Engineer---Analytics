# %% [markdown]
# # Shockwave Event Detection in Sensor Arrays
#
# Detect and localize shockwave-like events across distributed sensor arrays using benchmark waveform datasets or synthetic propagation simulations.

# %%
from pathlib import Path
from projects.shockwave_event_detection_in_sensor_arrays.src.pipeline import run_shockwave_event_detection_in_sensor_arrays_pipeline
artifacts = run_shockwave_event_detection_in_sensor_arrays_pipeline(Path('projects/shockwave_event_detection_in_sensor_arrays'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
