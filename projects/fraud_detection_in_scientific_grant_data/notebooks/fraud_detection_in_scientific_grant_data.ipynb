# %% [markdown]
# # Fraud Detection in Scientific Grant Data
#
# Detect suspicious funding patterns and anomalies in grant allocation datasets.

# %%
from pathlib import Path
from projects.fraud_detection_in_scientific_grant_data.src.pipeline import run_fraud_detection_in_scientific_grant_data_pipeline
artifacts = run_fraud_detection_in_scientific_grant_data_pipeline(Path('projects/fraud_detection_in_scientific_grant_data'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
