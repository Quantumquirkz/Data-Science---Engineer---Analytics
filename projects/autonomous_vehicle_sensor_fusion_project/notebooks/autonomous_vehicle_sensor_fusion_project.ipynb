# %% [markdown]
# # Autonomous Vehicle Sensor Fusion Project
#
# Fuse camera, LiDAR, GPS, and inertial data for improved localization or perception using autonomous driving benchmark datasets rather than collecting sensor data yourself.

# %%
from pathlib import Path
from projects.autonomous_vehicle_sensor_fusion_project.src.pipeline import run_autonomous_vehicle_sensor_fusion_project_pipeline
artifacts = run_autonomous_vehicle_sensor_fusion_project_pipeline(Path('projects/autonomous_vehicle_sensor_fusion_project'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
