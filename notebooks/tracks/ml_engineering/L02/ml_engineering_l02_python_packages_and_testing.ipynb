# %% [markdown]
# # ML Engineering L02: Python Packages And Testing
#
# Mission: `p040-mle-l02-m01`
# Project anchor: `p040` `large_scale_log_compression_and_analytics`
#
# ## Guiding question
#
# How does a model become a reliable, reproducible, inspectable software system?
#
# ## Level intent
#
# Structure ML code as importable modules with explicit contracts.
#
# ## Mathematical spine
#
# $$\mathcal{L}(\theta) = \frac{1}{n}\sum_{i=1}^n \ell\left(f_\theta(x_i), y_i\right), \qquad \text{SLO}=\{\text{latency},\text{availability},\text{quality}\}$$

# %% [markdown]
# ## Competencies
#
# - Unit tests
# - Integration seams
# - Refactoring pressure
#
# ## Method
#
# Translate concepts into reproducible tables, arrays, files, or modules.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'ml_engineering'
level = 'L02'
project_id = 'p040'
project_slug = 'large_scale_log_compression_and_analytics'
project_readme = Path('projects/large_scale_log_compression_and_analytics/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.large_scale_log_compression_and_analytics.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/large_scale_log_compression_and_analytics/README.md`](../../../projects/large_scale_log_compression_and_analytics/README.md)
# - Project notebook: `projects/large_scale_log_compression_and_analytics/notebooks/large_scale_log_compression_and_analytics.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
