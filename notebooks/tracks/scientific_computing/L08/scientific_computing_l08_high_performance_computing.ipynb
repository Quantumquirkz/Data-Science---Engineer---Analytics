# %% [markdown]
# # Scientific Computing L08: High-Performance Computing
#
# This notebook teaches the level step by step. It assumes you are willing to slow down and define the idea before running project code.
#
# **Mission:** `p067-sc-l08-m01`
# **Project anchor:** `p067` `real_time_manufacturing_yield_dashboard`
#
# ## Start from zero
#
# Reason about memory, vectorization, and parallel workloads for simulation.
#
# Plain question: **How do equations, numerical methods, and simulations become trustworthy computational evidence?**

# %% [markdown]
# ## 1. Vocabulary before tools
#
# Before using libraries, define the vocabulary.
#
# - `Memory bandwidth`: write a one-sentence definition.
# - `Parallel decomposition`: point to where it appears in data, code, math, or system design.
# - `Profiling`: explain the risk if it is ignored.
#
# A useful rule: if you cannot explain the word with a tiny example, you are not ready to automate it.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'scientific_computing'
level = 'L08'
project_id = 'p067'
project_slug = 'real_time_manufacturing_yield_dashboard'
project_readme = Path('projects') / project_slug / 'README.md'
project_notebook = 'projects/real_time_manufacturing_yield_dashboard/notebooks/real_time_manufacturing_yield_dashboard.ipynb'

{
    'repo_root': str(repo_root),
    'track': track,
    'level': level,
    'project_readme_exists': project_readme.exists(),
    'project_notebook': project_notebook,
}

# %% [markdown]
# ## 2. The core idea slowly
#
# This is the **Scale** stage. Your job is to preserve clarity when data, compute, users, or models grow.
#
# Scaling a weak idea makes the weakness more expensive.
#
# Every level in this repository follows the same reasoning chain:
#
# 1. Observation: what is directly visible?
# 2. Representation: how is it encoded?
# 3. Operation: what do we compute or transform?
# 4. Evidence: what output supports the claim?
# 5. Limitation: what could still be wrong?

# %% [markdown]
# ## 3. Mathematical spine
#
# \[\frac{d\mathbf{x}}{dt} = f(\mathbf{x}, t), \qquad \epsilon_h = \lVert x - x_h \rVert\]
#
# A differential equation describes how a state changes over time. Numerical error measures the gap between the ideal solution and the computed approximation.
#
# At this level, do not try to memorize symbols. Translate each symbol into words and connect it to the project anchor.

# %%
learning_card = {
    'track': 'Scientific Computing',
    'level': 'L08',
    'title': 'High-Performance Computing',
    'mission': 'p067-sc-l08-m01',
    'project': 'real_time_manufacturing_yield_dashboard',
    'competencies': ['Memory bandwidth', 'Parallel decomposition', 'Profiling'],
    'first_principle': 'scientific computing starts with state variables, units, laws or assumptions, and numerical error',
}

for key, value in learning_card.items():
    print(f"{key}: {value}")

# %% [markdown]
# ## 4. Worked micro-example
#
# Imagine simulating a moving object. You name the state variables, attach units, and ask how profiling changes the trustworthiness of the computed trajectory.
#
# Now answer:
#
# - What is the observation?
# - What is the representation?
# - What operation is being applied?
# - What output would count as evidence?
# - What limitation remains?

# %%
exercise = {
    'observation': '',
    'representation': '',
    'operation': '',
    'evidence': '',
    'limitation': '',
}

# Fill the strings above as notes while studying. Keeping them in a dict makes
# the reasoning explicit and easy to revise.
exercise

# %% [markdown]
# ## 5. Connect to the project
#
# Open the project README and notebook after you understand the vocabulary.
#
# Project README path:
#
# ```text
# projects/real_time_manufacturing_yield_dashboard/README.md
# ```
#
# Run command:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.real_time_manufacturing_yield_dashboard.src.pipeline
# ```
#
# Do not worry if the project feels more advanced than the level. Your task is to identify where this level's idea appears inside the project.

# %% [markdown]
# ## 6. Self-check without grades
#
# Mark yourself honestly:
#
# - `exploring`: I can repeat the words.
# - `practiced`: I can run this notebook and answer the prompts.
# - `demonstrated`: I can explain `High-Performance Computing` using `real_time_manufacturing_yield_dashboard`.
# - `extended`: I changed an assumption or proposed a stronger experiment.
#
# Before leaving the notebook, write one sentence for each competency: `Memory bandwidth`, `Parallel decomposition`, and `Profiling`.
