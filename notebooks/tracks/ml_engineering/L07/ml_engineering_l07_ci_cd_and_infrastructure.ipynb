# %% [markdown]
# # ML Engineering L07: CI/CD And Infrastructure
#
# Mission: `p076-mle-l07-m01`
# Project anchor: `p076` `scientific_data_platform_for_multi_modal_experiments`
#
# ## Guiding question
#
# How does a model become a reliable, reproducible, inspectable software system?
#
# ## Level intent
#
# Use automation to protect build, test, and deployment paths.
#
# ## Mathematical spine
#
# $$\mathcal{L}(\theta) = \frac{1}{n}\sum_{i=1}^n \ell\left(f_\theta(x_i), y_i\right), \qquad \text{SLO}=\{\text{latency},\text{availability},\text{quality}\}$$

# %% [markdown]
# ## Competencies
#
# - Build validation
# - Release gates
# - Rollback logic
#
# ## Method
#
# Handle time, change, automation, or inverse reasoning under constraints.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'ml_engineering'
level = 'L07'
project_id = 'p076'
project_slug = 'scientific_data_platform_for_multi_modal_experiments'
project_readme = Path('projects/scientific_data_platform_for_multi_modal_experiments/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.scientific_data_platform_for_multi_modal_experiments.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/scientific_data_platform_for_multi_modal_experiments/README.md`](../../../projects/scientific_data_platform_for_multi_modal_experiments/README.md)
# - Project notebook: `projects/scientific_data_platform_for_multi_modal_experiments/notebooks/scientific_data_platform_for_multi_modal_experiments.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
