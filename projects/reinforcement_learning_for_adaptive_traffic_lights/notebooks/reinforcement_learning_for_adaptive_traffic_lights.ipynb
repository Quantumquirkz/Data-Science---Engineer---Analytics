# %% [markdown]
# # Reinforcement Learning for Adaptive Traffic Lights
#
# Train an adaptive system to optimize urban traffic signal timing.

# %%
from pathlib import Path
from projects.reinforcement_learning_for_adaptive_traffic_lights.src.pipeline import run_reinforcement_learning_for_adaptive_traffic_lights_pipeline
artifacts = run_reinforcement_learning_for_adaptive_traffic_lights_pipeline(Path('projects/reinforcement_learning_for_adaptive_traffic_lights'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
