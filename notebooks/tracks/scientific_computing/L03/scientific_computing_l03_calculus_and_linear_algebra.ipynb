# %% [markdown]
# # Scientific Computing L03: Calculus And Linear Algebra
#
# Mission: `p022-sc-l03-m01`
# Project anchor: `p022` `experimental_physics_outlier_lab`
#
# ## Guiding question
#
# How do equations, numerical methods, and simulations become trustworthy computational evidence?
#
# ## Level intent
#
# Use derivatives, integrals, and matrix structure to reason about models.
#
# ## Mathematical spine
#
# $$\frac{d\mathbf{x}}{dt} = f(\mathbf{x}, t), \qquad \epsilon_h = \lVert x - x_h \rVert$$

# %% [markdown]
# ## Competencies
#
# - Gradients
# - Eigenstructure
# - Conditioning
#
# ## Method
#
# Reason about structure: distributions, schemas, workflows, or equations.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'scientific_computing'
level = 'L03'
project_id = 'p022'
project_slug = 'experimental_physics_outlier_lab'
project_readme = Path('projects/experimental_physics_outlier_lab/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.experimental_physics_outlier_lab.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/experimental_physics_outlier_lab/README.md`](../../../projects/experimental_physics_outlier_lab/README.md)
# - Project notebook: `projects/experimental_physics_outlier_lab/notebooks/experimental_physics_outlier_lab.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
