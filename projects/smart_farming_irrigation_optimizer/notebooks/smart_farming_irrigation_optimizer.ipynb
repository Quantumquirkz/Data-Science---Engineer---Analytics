# %% [markdown]
# # Smart Farming Irrigation Optimizer
#
# Optimize irrigation schedules using open weather, soil moisture, and crop condition datasets or agricultural simulations.

# %%
from pathlib import Path
from projects.smart_farming_irrigation_optimizer.src.pipeline import run_smart_farming_irrigation_optimizer_pipeline
artifacts = run_smart_farming_irrigation_optimizer_pipeline(Path('projects/smart_farming_irrigation_optimizer'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
