# %% [markdown]
# # Data Engineering L10: Production Data Platform Capstone
#
# Mission: `p084-de-l10-m01`
# Project anchor: `p084` `smart_building_thermal_dynamics_model`
#
# ## Guiding question
#
# How does data move, stay valid, and remain trustworthy at scale?
#
# ## Level intent
#
# Defend a full platform design with reliability, observability, and change management.
#
# ## Mathematical spine
#
# $$\text{throughput} = \frac{\text{records processed}}{\text{time}}, \qquad \text{latency} = t_{out} - t_{in}$$

# %% [markdown]
# ## Competencies
#
# - Operational SLOs
# - Platform contracts
# - Migration plans
#
# ## Method
#
# Integrate the full track into a capstone-level system narrative.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'data_engineering'
level = 'L10'
project_id = 'p084'
project_slug = 'smart_building_thermal_dynamics_model'
project_readme = Path('projects/smart_building_thermal_dynamics_model/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.smart_building_thermal_dynamics_model.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/smart_building_thermal_dynamics_model/README.md`](../../../projects/smart_building_thermal_dynamics_model/README.md)
# - Project notebook: `projects/smart_building_thermal_dynamics_model/notebooks/smart_building_thermal_dynamics_model.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
