# %% [markdown]
# # Dynamic Pricing Under Uncertainty
#
# Optimize prices using historical demand and uncertain future conditions.

# %%
from pathlib import Path
from projects.dynamic_pricing_under_uncertainty.src.pipeline import run_dynamic_pricing_under_uncertainty_pipeline
artifacts = run_dynamic_pricing_under_uncertainty_pipeline(Path('projects/dynamic_pricing_under_uncertainty'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
