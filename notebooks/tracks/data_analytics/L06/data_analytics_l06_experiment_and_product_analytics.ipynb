# %% [markdown]
# # Data Analytics L06: Experiment And Product Analytics
#
# Mission: `p046-da-l06-m01`
# Project anchor: `p046` `material_fatigue_prediction`
#
# ## Guiding question
#
# What happened, why did it happen, and what decision should follow?
#
# ## Level intent
#
# Measure interventions, funnels, and behavioral changes with discipline.
#
# ## Mathematical spine
#
# $$\text{rate} = \frac{\Delta y}{\Delta t}, \qquad \bar{x} = \frac{1}{n}\sum_{i=1}^n x_i$$

# %% [markdown]
# ## Competencies
#
# - A/B test logic
# - Bias in instrumentation
# - Attribution boundaries
#
# ## Method
#
# Track uncertainty, variation, retries, or experimental lineage.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'data_analytics'
level = 'L06'
project_id = 'p046'
project_slug = 'material_fatigue_prediction'
project_readme = Path('projects/material_fatigue_prediction/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.material_fatigue_prediction.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/material_fatigue_prediction/README.md`](../../../projects/material_fatigue_prediction/README.md)
# - Project notebook: `projects/material_fatigue_prediction/notebooks/material_fatigue_prediction.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
