# %% [markdown]
# # Blood Flow Proxy Prediction
#
# Predict blood flow metrics from partial physiological measurements using public biomedical datasets or simulation outputs.

# %%
from pathlib import Path
from projects.blood_flow_proxy_prediction.src.pipeline import run_blood_flow_proxy_prediction_pipeline
artifacts = run_blood_flow_proxy_prediction_pipeline(Path('projects/blood_flow_proxy_prediction'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
