# %% [markdown]
# # Data Analytics L09: Analytics Engineering And Governance
#
# Mission: `p074-da-l09-m01`
# Project anchor: `p074` `satellite_image_change_detection`
#
# ## Guiding question
#
# What happened, why did it happen, and what decision should follow?
#
# ## Level intent
#
# Unify metrics definitions, data contracts, and governance checks.
#
# ## Mathematical spine
#
# $$\text{rate} = \frac{\Delta y}{\Delta t}, \qquad \bar{x} = \frac{1}{n}\sum_{i=1}^n x_i$$

# %% [markdown]
# ## Competencies
#
# - Metric lineage
# - Access policy
# - Backfill risk
#
# ## Method
#
# Add governance, responsibility, numerical rigor, or scientific critique.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'data_analytics'
level = 'L09'
project_id = 'p074'
project_slug = 'satellite_image_change_detection'
project_readme = Path('projects/satellite_image_change_detection/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.satellite_image_change_detection.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/satellite_image_change_detection/README.md`](../../../projects/satellite_image_change_detection/README.md)
# - Project notebook: `projects/satellite_image_change_detection/notebooks/satellite_image_change_detection.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
