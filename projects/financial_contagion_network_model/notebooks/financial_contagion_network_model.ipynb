# %% [markdown]
# # Financial Contagion Network Model
#
# Model propagation of distress across connected institutions using network data.

# %%
from pathlib import Path
from projects.financial_contagion_network_model.src.pipeline import run_financial_contagion_network_model_pipeline
artifacts = run_financial_contagion_network_model_pipeline(Path('projects/financial_contagion_network_model'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
