# %% [markdown]
# # Data Engineering L07: Streaming And Event Systems
#
# Mission: `p066-de-l07-m01`
# Project anchor: `p066` `rare_disease_signal_mining`
#
# ## Guiding question
#
# How does data move, stay valid, and remain trustworthy at scale?
#
# ## Level intent
#
# Reason about event time, out-of-order data, and durable consumers.
#
# ## Mathematical spine
#
# $$\text{throughput} = \frac{\text{records processed}}{\text{time}}, \qquad \text{latency} = t_{out} - t_{in}$$

# %% [markdown]
# ## Competencies
#
# - Watermarks
# - At-least-once tradeoffs
# - Stateful streams
#
# ## Method
#
# Handle time, change, automation, or inverse reasoning under constraints.

# %%
from pathlib import Path

repo_root = Path.cwd()
track = 'data_engineering'
level = 'L07'
project_id = 'p066'
project_slug = 'rare_disease_signal_mining'
project_readme = Path('projects/rare_disease_signal_mining/README.md')
project_readme.exists(), track, level, project_id, project_slug

# %% [markdown]
# ## Run locally with uv
#
# Use the project command from the repository root:
#
# ```bash
# PYTHONPATH=src:. uv run python -m projects.rare_disease_signal_mining.src.pipeline
# ```
#
# For Colab, clone the repository first, install with `uv` or `%pip` as needed, then keep paths relative to the cloned repository root.

# %% [markdown]
# ## Practice
#
# 1. State the observation unit or system state.
# 2. Name the input, output, and one hidden assumption.
# 3. Run or inspect the project anchor and describe what evidence it produces.
# 4. Write one limitation and one extension that would make the result stronger.

# %% [markdown]
# ## Project surfaces
#
# - README: [`projects/rare_disease_signal_mining/README.md`](../../../projects/rare_disease_signal_mining/README.md)
# - Project notebook: `projects/rare_disease_signal_mining/notebooks/rare_disease_signal_mining.ipynb`
# - Evidence status options: `exploring`, `practiced`, `demonstrated`, `extended`
