# %% [markdown]
# # Data Assimilation for Environmental Systems
#
# Fuse simulation outputs and observed data to improve state estimation.

# %%
from pathlib import Path
from projects.data_assimilation_for_environmental_systems.src.pipeline import run_data_assimilation_for_environmental_systems_pipeline
artifacts = run_data_assimilation_for_environmental_systems_pipeline(Path('projects/data_assimilation_for_environmental_systems'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
