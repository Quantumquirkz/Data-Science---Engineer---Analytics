# %% [markdown]
# # Recommender System for Scientific Papers
#
# Recommend papers based on topic similarity, citation graph structure, and user interests.

# %%
from pathlib import Path
from projects.recommender_system_for_scientific_papers.src.pipeline import run_recommender_system_for_scientific_papers_pipeline
artifacts = run_recommender_system_for_scientific_papers_pipeline(Path('projects/recommender_system_for_scientific_papers'))
artifacts.model_result.metrics

# %% [markdown]
# Generated artifacts are saved to `data/processed/reports/` for review and dashboarding.
